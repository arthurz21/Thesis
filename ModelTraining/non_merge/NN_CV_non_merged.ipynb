# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, accuracy_score, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import resample
import copy

# %%
derivation_cohort = pd.read_csv("Derivation_dataset.csv")
external_validation_cohort = pd.read_csv("External_validation_dataset.csv")

# %%
y = derivation_cohort['Outcome_Occlusion_MI']
X = derivation_cohort.drop('Outcome_Occlusion_MI', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, random_state = 99)

y_val = external_validation_cohort['Outcome_Occlusion_MI']
X_val = external_validation_cohort.drop('Outcome_Occlusion_MI', axis=1)

for el in X_train.columns:
    X_train[el].fillna(X_train[el].mode()[0], inplace=True)
    X_test[el].fillna(X_train[el].mode()[0], inplace=True)
    X_val[el].fillna(X_train[el].mode()[0], inplace=True)

y_train = np.ravel(np.array(y_train.values))
y_test = np.ravel(np.array(y_test.values))
y_val = np.ravel(np.array(y_val.values))

columns = X_train.columns

X_train = np.array(X_train.values)
X_test = np.array(X_test.values)
X_val = np.array(X_val.values)

scaler = preprocessing.StandardScaler().fit(X_train) # Compute mean and std of training set
X_train = scaler.transform(X_train, copy=True)
X_test = scaler.transform(X_test, copy=True) # Standardize X_test using training mean and std
X_val = scaler.transform(X_val, copy=True)
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_95588\3933838254.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_95588\3933838254.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_95588\3933838254.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_val[el].fillna(X_train[el].mode()[0], inplace=True)

# %%
torch.manual_seed(99)
np.random.seed(99)

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Convert pandas DataFrames to NumPy arrays, then to PyTorch tensors
X_train_tensor = torch.FloatTensor(X_train.values if isinstance(X_train, pd.DataFrame) else X_train)
y_train_tensor = torch.FloatTensor(y_train.values if isinstance(y_train, pd.Series) else y_train)
X_val_tensor = torch.FloatTensor(X_val.values if isinstance(X_val, pd.DataFrame) else X_val)
y_val_tensor = torch.FloatTensor(y_val.values if isinstance(y_val, pd.Series) else y_val)
X_test_tensor = torch.FloatTensor(X_test.values if isinstance(X_test, pd.DataFrame) else X_test)
y_test_tensor = torch.FloatTensor(y_test.values if isinstance(y_test, pd.Series) else y_test)

# Create PyTorch datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor.view(-1, 1))
val_dataset = TensorDataset(X_val_tensor, y_val_tensor.view(-1, 1))
test_dataset = TensorDataset(X_test_tensor, y_test_tensor.view(-1, 1))

# Get input dimensions
n_features = X_train.shape[1]
# Out:
# Using device: cuda:0

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dims, dropout_rate=0.3):
        super(BinaryClassifier, self).__init__()
        
        layers = []
        prev_dim = input_dim
        
        # Create hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(prev_dim, hidden_dim))
            layers.append(nn.ReLU())
            layers.append(nn.BatchNorm1d(hidden_dim))
            layers.append(nn.Dropout(dropout_rate))
            prev_dim = hidden_dim
        
        # Output layer - NO sigmoid here because we'll use BCEWithLogitsLoss
        self.feature_layers = nn.Sequential(*layers)
        self.output_layer = nn.Linear(prev_dim, 1)
    
    def forward(self, x):
        features = self.feature_layers(x)
        # Return raw logits - BCEWithLogitsLoss will handle the sigmoid internally
        return self.output_layer(features)

# %%
# Define training function
# Modify train_model function to return all losses for each epoch
def train_model_with_history(model, train_loader, val_loader, criterion, optimizer, n_epochs=100, patience=5):
    model = model.to(device)
    
    # To track the best model
    best_val_loss = float('inf')
    best_model_state = None
    epochs_no_improve = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    
    for epoch in range(n_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Zero the parameter gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            # Fix dimension issue - don't double unsqueeze the labels
            loss = criterion(outputs, labels.float().view(-1, 1))
            
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * inputs.size(0)
        
        # Calculate average training loss
        train_loss = train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                
                # Forward pass
                outputs = model(inputs)
                # Fix dimension issue here too (in validation loop)
                loss = criterion(outputs, labels.float().view(-1, 1))
                
                val_loss += loss.item() * inputs.size(0)
        
        # Calculate average validation loss
        val_loss = val_loss / len(val_loader.dataset)
        val_losses.append(val_loss)
        
        # Print epoch results
        print(f'Epoch {epoch+1}/{n_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}')
        
        # Check if this is the best model so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict().copy()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        # Early stopping
        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after epoch {epoch+1}')
            break
    
    # Load the best model
    model.load_state_dict(best_model_state)
    
    return model, train_losses, val_losses
# Define prediction function
def predict(model, data_loader):
    model.eval()
    predictions = []
    
    model.to(device)
    
    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            
            # Get raw logits
            logits = model(inputs)
            
            # Apply sigmoid to get probabilities
            probs = torch.sigmoid(logits)
            
            predictions.append(probs.cpu().numpy())
    
    return np.vstack(predictions)

# %%
# Define custom ROC curve plotting function
def plot_PyTorch_ROC_curve(fpr, tpr, roc_auc, title):
    plt.figure(figsize=[5, 5])
    plt.title(title)
    plt.plot(fpr, tpr, color='r',
            label=f'PyTorch NN (AUC = {roc_auc:.3f})',
            lw=2, alpha=.8)
    plt.plot([0, 1], [0, 1], linestyle='--', lw=1, color='grey', alpha=.5)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate = 1 - Specificity')
    plt.ylabel('True Positive Rate = Sensitivity')
    plt.legend(loc="lower right")
    plt.show()

# %%
def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=1000, alpha=0.05):
    """
    Compute 95% confidence interval using bootstrapping for any metric.
    
    Parameters:
    - y_true: Ground truth labels (0 or 1).
    - y_pred: Predicted values (either probabilities or binary predictions).
    - metric_fn: Metric function (roc_auc_score, recall_score, f1_score).
    - n_bootstrap: Number of bootstrap resamples.
    - alpha: Significance level (default 0.05 for 95% CI).

    Returns:
    - Lower and upper bound of the confidence interval.
    """
    scores = []
    
    for _ in range(n_bootstrap):
        # Resample dataset with replacement
        indices = resample(range(len(y_true)), replace=True, n_samples=len(y_true))
        y_true_bootstrap = np.array(y_true)[indices]
        y_pred_bootstrap = np.array(y_pred)[indices]

        # Special case for AUROC: Use roc_curve and auc()
        if metric_fn == "auroc":
            fpr, tpr, _ = roc_curve(y_true_bootstrap, y_pred_bootstrap)
            score = auc(fpr, tpr)
        else:
            score = metric_fn(y_true_bootstrap, y_pred_bootstrap)

        scores.append(score)
    
    # Compute confidence interval
    lower_bound = np.percentile(scores, 100 * (alpha / 2))
    upper_bound = np.percentile(scores, 100 * (1 - alpha / 2))
    
    return lower_bound, upper_bound

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, SubsetRandomSampler
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import pandas as pd
from tqdm.notebook import tqdm

# Binary Classifier Neural Network
class BinaryClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dims, dropout_rate=0.3):
        super(BinaryClassifier, self).__init__()
        
        layers = []
        prev_dim = input_dim
        
        # Create hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(prev_dim, hidden_dim))
            layers.append(nn.ReLU())
            layers.append(nn.BatchNorm1d(hidden_dim))
            layers.append(nn.Dropout(dropout_rate))
            prev_dim = hidden_dim
        
        # Output layer
        self.feature_layers = nn.Sequential(*layers)
        self.output_layer = nn.Linear(prev_dim, 1)
    
    def forward(self, x):
        features = self.feature_layers(x)
        return self.output_layer(features)

# Try fewer hyperparameter combinations
def quick_cv_search(X, y):
    # Convert DataFrames to numpy arrays if needed
    if hasattr(X, 'values'):
        X = X.values
    if hasattr(y, 'values'):
        y = y.values
    
    hidden_dims_options = [
         [64], [128], [256],
         [64, 32], [128, 64], [256, 128],
    ]  # Keeping all 10 options
    
    dropout_options = [0.6, 0.7]  # 3 options instead of 5
    
    lr_options = [0.001, 0.005]  # 2 options instead of 4
    
    batch_size_options = [64, 128]  # 2 options instead of 3
    
    weight_decay_options = [0.0001, 0.001]  # 2 options instead of 3
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    X_tensor = torch.FloatTensor(X)
    y_tensor = torch.FloatTensor(y)
    
    kf = KFold(n_splits=10, shuffle=True, random_state=42)
    best_config = None
    best_auroc = 0
    results = []
    
    total_configs = len(hidden_dims_options) * len(dropout_options) * len(lr_options) * len(batch_size_options) * len(weight_decay_options)
    print(f"Running 10-fold CV for {total_configs} configurations")
    
    # Simplified version - using fixed batch size and weight decay to test the approach
    # Remove this section and uncomment the full search when ready
    config_count = 0
    for hidden_dims in hidden_dims_options:
        for dropout in dropout_options:
            for lr in lr_options:
                for batch_size in batch_size_options:
                    for weight_decay in weight_decay_options:
                        config_count += 1
                        print(f"Config {config_count}/{total_configs}: hidden={hidden_dims}, dropout={dropout}, lr={lr}, batch={batch_size}, wd={weight_decay}")
                        fold_scores = []
                        
                        for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
                            # Create data loaders
                            train_loader = DataLoader(
                                TensorDataset(X_tensor, y_tensor),
                                batch_size=batch_size,
                                sampler=SubsetRandomSampler(train_idx)
                            )
                            val_loader = DataLoader(
                                TensorDataset(X_tensor, y_tensor),
                                batch_size=batch_size,
                                sampler=SubsetRandomSampler(val_idx)
                            )
                            
                            # Create and train model
                            model = BinaryClassifier(X.shape[1], hidden_dims, dropout)
                            criterion = nn.BCEWithLogitsLoss()
                            optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
                            
                            # Train the model with a fixed initial state
                            model = train_model(model, train_loader, val_loader, criterion, optimizer, device)
                            
                            # Evaluate model
                            model.eval()
                            all_preds = []
                            all_labels = []
                            
                            with torch.no_grad():
                                for inputs, labels in val_loader:
                                    inputs, labels = inputs.to(device), labels.to(device)
                                    outputs = model(inputs)
                                    probs = torch.sigmoid(outputs)
                                    all_preds.extend(probs.cpu().numpy().flatten())
                                    all_labels.extend(labels.cpu().numpy().flatten())
                            
                            auroc = roc_auc_score(all_labels, all_preds)
                            fold_scores.append(auroc)
                            print(f"  Fold {fold+1}/10: AUROC = {auroc:.4f}")
                        
                        # Calculate mean performance
                        mean_auroc = np.mean(fold_scores)
                        std_auroc = np.std(fold_scores)
                        print(f"  Mean AUROC: {mean_auroc:.4f} ± {std_auroc:.4f}")
                        
                        results.append({
                            'hidden_dims': hidden_dims,
                            'dropout': dropout,
                            'learning_rate': lr,
                            'batch_size': batch_size,
                            'weight_decay': weight_decay,
                            'mean_auroc': mean_auroc,
                            'std_auroc': std_auroc
                        })
                        
                        if mean_auroc > best_auroc:
                            best_auroc = mean_auroc
                            best_config = {
                                'hidden_dims': hidden_dims,
                                'dropout_rate': dropout,
                                'learning_rate': lr,
                                'batch_size': batch_size,
                                'weight_decay': weight_decay,
                                'mean_auroc': mean_auroc
                            }
    
    results_df = pd.DataFrame(results).sort_values('mean_auroc', ascending=False)
    
    print("\nTop 5 Hyperparameter Configurations:")
    print(results_df.head(5))
    
    print("\nBest Configuration:")
    print(f"Hidden Dimensions: {best_config['hidden_dims']}")
    print(f"Dropout Rate: {best_config['dropout_rate']}")
    print(f"Learning Rate: {best_config['learning_rate']}")
    print(f"Batch Size: {best_config['batch_size']}")
    print(f"Weight Decay: {best_config['weight_decay']}")
    print(f"Mean AUROC: {best_config['mean_auroc']:.4f}")
    
    return best_config, results_df

# Simplified training function
def train_model(model, train_loader, val_loader, criterion, optimizer, device, n_epochs=30, patience=5):
    model = model.to(device)
    
    # Save initial state
    best_val_loss = float('inf')
    best_model_state = model.state_dict().copy()  # Initialize with starting state
    epochs_no_improve = 0
    
    for epoch in range(n_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels.float())
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs.squeeze(), labels.float())
                val_loss += loss.item()
        
        # Check early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict().copy()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                break
    
    # Load best model
    model.load_state_dict(best_model_state)
    return model

# Run a quick search
best_config, results = quick_cv_search(X_train, y_train)
# Out:
# Using device: cuda:0
# Running 10-fold CV for 96 configurations
# Config 1/96: hidden=[64], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7757
#   Fold 2/10: AUROC = 0.8671
#   Fold 3/10: AUROC = 0.9140
#   Fold 4/10: AUROC = 0.9193
#   Fold 5/10: AUROC = 0.8832
#   Fold 6/10: AUROC = 0.8609
#   Fold 7/10: AUROC = 0.8417
#   Fold 8/10: AUROC = 0.9711
#   Fold 9/10: AUROC = 0.7317
#   Fold 10/10: AUROC = 0.8384
#   Mean AUROC: 0.8603 ± 0.0661
# Config 2/96: hidden=[64], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8166
#   Fold 2/10: AUROC = 0.8798
#   Fold 3/10: AUROC = 0.8284
#   Fold 4/10: AUROC = 0.9491
#   Fold 5/10: AUROC = 0.8703
#   Fold 6/10: AUROC = 0.8934
#   Fold 7/10: AUROC = 0.8606
#   Fold 8/10: AUROC = 0.9591
#   Fold 9/10: AUROC = 0.7513
#   Fold 10/10: AUROC = 0.8212
#   Mean AUROC: 0.8630 ± 0.0596
# Config 3/96: hidden=[64], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7909
#   Fold 2/10: AUROC = 0.8940
#   Fold 3/10: AUROC = 0.8378
#   Fold 4/10: AUROC = 0.9394
#   Fold 5/10: AUROC = 0.8738
#   Fold 6/10: AUROC = 0.9210
#   Fold 7/10: AUROC = 0.8851
#   Fold 8/10: AUROC = 0.9629
#   Fold 9/10: AUROC = 0.6968
#   Fold 10/10: AUROC = 0.8642
#   Mean AUROC: 0.8666 ± 0.0735
# Config 4/96: hidden=[64], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7972
#   Fold 2/10: AUROC = 0.8623
#   Fold 3/10: AUROC = 0.8531
#   Fold 4/10: AUROC = 0.9271
#   Fold 5/10: AUROC = 0.9002
#   Fold 6/10: AUROC = 0.9222
#   Fold 7/10: AUROC = 0.8503
#   Fold 8/10: AUROC = 0.9582
#   Fold 9/10: AUROC = 0.7250
#   Fold 10/10: AUROC = 0.8435
#   Mean AUROC: 0.8639 ± 0.0649
# Config 5/96: hidden=[64], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8003
#   Fold 2/10: AUROC = 0.8834
#   Fold 3/10: AUROC = 0.8593
#   Fold 4/10: AUROC = 0.9526
#   Fold 5/10: AUROC = 0.8840
#   Fold 6/10: AUROC = 0.9183
#   Fold 7/10: AUROC = 0.8640
#   Fold 8/10: AUROC = 0.9433
#   Fold 9/10: AUROC = 0.7901
#   Fold 10/10: AUROC = 0.8472
#   Mean AUROC: 0.8743 ± 0.0516
# Config 6/96: hidden=[64], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8063
#   Fold 2/10: AUROC = 0.8590
#   Fold 3/10: AUROC = 0.8815
#   Fold 4/10: AUROC = 0.9325
#   Fold 5/10: AUROC = 0.9096
#   Fold 6/10: AUROC = 0.8930
#   Fold 7/10: AUROC = 0.8953
#   Fold 8/10: AUROC = 0.9488
#   Fold 9/10: AUROC = 0.7962
#   Fold 10/10: AUROC = 0.8704
#   Mean AUROC: 0.8793 ± 0.0466
# Config 7/96: hidden=[64], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7917
#   Fold 2/10: AUROC = 0.8560
#   Fold 3/10: AUROC = 0.8554
#   Fold 4/10: AUROC = 0.9479
#   Fold 5/10: AUROC = 0.9181
#   Fold 6/10: AUROC = 0.9016
#   Fold 7/10: AUROC = 0.8606
#   Fold 8/10: AUROC = 0.9559
#   Fold 9/10: AUROC = 0.7043
#   Fold 10/10: AUROC = 0.8512
#   Mean AUROC: 0.8643 ± 0.0713
# Config 8/96: hidden=[64], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8010
#   Fold 2/10: AUROC = 0.8649
#   Fold 3/10: AUROC = 0.8617
#   Fold 4/10: AUROC = 0.9338
#   Fold 5/10: AUROC = 0.9012
#   Fold 6/10: AUROC = 0.8611
#   Fold 7/10: AUROC = 0.8792
#   Fold 8/10: AUROC = 0.9486
#   Fold 9/10: AUROC = 0.7766
#   Fold 10/10: AUROC = 0.8601
#   Mean AUROC: 0.8688 ± 0.0500
# Config 9/96: hidden=[64], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7863
#   Fold 2/10: AUROC = 0.8468
#   Fold 3/10: AUROC = 0.8190
#   Fold 4/10: AUROC = 0.9306
#   Fold 5/10: AUROC = 0.8862
#   Fold 6/10: AUROC = 0.9228
#   Fold 7/10: AUROC = 0.8909
#   Fold 8/10: AUROC = 0.9541
#   Fold 9/10: AUROC = 0.7223
#   Fold 10/10: AUROC = 0.8406
#   Mean AUROC: 0.8600 ± 0.0679
# Config 10/96: hidden=[64], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8313
#   Fold 2/10: AUROC = 0.8819
#   Fold 3/10: AUROC = 0.8819
#   Fold 4/10: AUROC = 0.9350
#   Fold 5/10: AUROC = 0.9071
#   Fold 6/10: AUROC = 0.8883
#   Fold 7/10: AUROC = 0.9039
#   Fold 8/10: AUROC = 0.9471
#   Fold 9/10: AUROC = 0.7667
#   Fold 10/10: AUROC = 0.8603
#   Mean AUROC: 0.8803 ± 0.0495
# Config 11/96: hidden=[64], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8164
#   Fold 2/10: AUROC = 0.8629
#   Fold 3/10: AUROC = 0.8699
#   Fold 4/10: AUROC = 0.9497
#   Fold 5/10: AUROC = 0.8815
#   Fold 6/10: AUROC = 0.9089
#   Fold 7/10: AUROC = 0.8993
#   Fold 8/10: AUROC = 0.9117
#   Fold 9/10: AUROC = 0.6707
#   Fold 10/10: AUROC = 0.8343
#   Mean AUROC: 0.8605 ± 0.0732
# Config 12/96: hidden=[64], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7911
#   Fold 2/10: AUROC = 0.8485
#   Fold 3/10: AUROC = 0.8505
#   Fold 4/10: AUROC = 0.9538
#   Fold 5/10: AUROC = 0.9079
#   Fold 6/10: AUROC = 0.8505
#   Fold 7/10: AUROC = 0.8436
#   Fold 8/10: AUROC = 0.9614
#   Fold 9/10: AUROC = 0.7035
#   Fold 10/10: AUROC = 0.8450
#   Mean AUROC: 0.8556 ± 0.0716
# Config 13/96: hidden=[64], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7974
#   Fold 2/10: AUROC = 0.8642
#   Fold 3/10: AUROC = 0.8834
#   Fold 4/10: AUROC = 0.9418
#   Fold 5/10: AUROC = 0.8870
#   Fold 6/10: AUROC = 0.9013
#   Fold 7/10: AUROC = 0.8966
#   Fold 8/10: AUROC = 0.9301
#   Fold 9/10: AUROC = 0.7683
#   Fold 10/10: AUROC = 0.8460
#   Mean AUROC: 0.8716 ± 0.0521
# Config 14/96: hidden=[64], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7858
#   Fold 2/10: AUROC = 0.8596
#   Fold 3/10: AUROC = 0.8613
#   Fold 4/10: AUROC = 0.9413
#   Fold 5/10: AUROC = 0.8957
#   Fold 6/10: AUROC = 0.8854
#   Fold 7/10: AUROC = 0.8935
#   Fold 8/10: AUROC = 0.9673
#   Fold 9/10: AUROC = 0.7409
#   Fold 10/10: AUROC = 0.8275
#   Mean AUROC: 0.8658 ± 0.0645
# Config 15/96: hidden=[64], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8003
#   Fold 2/10: AUROC = 0.8702
#   Fold 3/10: AUROC = 0.8527
#   Fold 4/10: AUROC = 0.9488
#   Fold 5/10: AUROC = 0.9034
#   Fold 6/10: AUROC = 0.9085
#   Fold 7/10: AUROC = 0.8765
#   Fold 8/10: AUROC = 0.9491
#   Fold 9/10: AUROC = 0.8116
#   Fold 10/10: AUROC = 0.8518
#   Mean AUROC: 0.8773 ± 0.0485
# Config 16/96: hidden=[64], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7879
#   Fold 2/10: AUROC = 0.8633
#   Fold 3/10: AUROC = 0.8564
#   Fold 4/10: AUROC = 0.9319
#   Fold 5/10: AUROC = 0.9032
#   Fold 6/10: AUROC = 0.9277
#   Fold 7/10: AUROC = 0.8969
#   Fold 8/10: AUROC = 0.9529
#   Fold 9/10: AUROC = 0.7430
#   Fold 10/10: AUROC = 0.8449
#   Mean AUROC: 0.8708 ± 0.0629
# Config 17/96: hidden=[128], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8098
#   Fold 2/10: AUROC = 0.8762
#   Fold 3/10: AUROC = 0.8027
#   Fold 4/10: AUROC = 0.9462
#   Fold 5/10: AUROC = 0.9022
#   Fold 6/10: AUROC = 0.9156
#   Fold 7/10: AUROC = 0.8772
#   Fold 8/10: AUROC = 0.9541
#   Fold 9/10: AUROC = 0.7272
#   Fold 10/10: AUROC = 0.8333
#   Mean AUROC: 0.8644 ± 0.0676
# Config 18/96: hidden=[128], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8003
#   Fold 2/10: AUROC = 0.8775
#   Fold 3/10: AUROC = 0.8260
#   Fold 4/10: AUROC = 0.9257
#   Fold 5/10: AUROC = 0.9141
#   Fold 6/10: AUROC = 0.9030
#   Fold 7/10: AUROC = 0.9039
#   Fold 8/10: AUROC = 0.9421
#   Fold 9/10: AUROC = 0.7519
#   Fold 10/10: AUROC = 0.8497
#   Mean AUROC: 0.8694 ± 0.0580
# Config 19/96: hidden=[128], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7833
#   Fold 2/10: AUROC = 0.8659
#   Fold 3/10: AUROC = 0.8444
#   Fold 4/10: AUROC = 0.9360
#   Fold 5/10: AUROC = 0.8847
#   Fold 6/10: AUROC = 0.8911
#   Fold 7/10: AUROC = 0.9064
#   Fold 8/10: AUROC = 0.9421
#   Fold 9/10: AUROC = 0.7379
#   Fold 10/10: AUROC = 0.8579
#   Mean AUROC: 0.8650 ± 0.0609
# Config 20/96: hidden=[128], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7897
#   Fold 2/10: AUROC = 0.8751
#   Fold 3/10: AUROC = 0.8401
#   Fold 4/10: AUROC = 0.9442
#   Fold 5/10: AUROC = 0.8818
#   Fold 6/10: AUROC = 0.9130
#   Fold 7/10: AUROC = 0.8677
#   Fold 8/10: AUROC = 0.9550
#   Fold 9/10: AUROC = 0.6712
#   Fold 10/10: AUROC = 0.8275
#   Mean AUROC: 0.8565 ± 0.0785
# Config 21/96: hidden=[128], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7982
#   Fold 2/10: AUROC = 0.8454
#   Fold 3/10: AUROC = 0.8307
#   Fold 4/10: AUROC = 0.9373
#   Fold 5/10: AUROC = 0.8780
#   Fold 6/10: AUROC = 0.9075
#   Fold 7/10: AUROC = 0.8416
#   Fold 8/10: AUROC = 0.9550
#   Fold 9/10: AUROC = 0.7984
#   Fold 10/10: AUROC = 0.8632
#   Mean AUROC: 0.8655 ± 0.0513
# Config 22/96: hidden=[128], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7816
#   Fold 2/10: AUROC = 0.8720
#   Fold 3/10: AUROC = 0.8495
#   Fold 4/10: AUROC = 0.9497
#   Fold 5/10: AUROC = 0.9129
#   Fold 6/10: AUROC = 0.8977
#   Fold 7/10: AUROC = 0.9119
#   Fold 8/10: AUROC = 0.9260
#   Fold 9/10: AUROC = 0.7323
#   Fold 10/10: AUROC = 0.8641
#   Mean AUROC: 0.8698 ± 0.0641
# Config 23/96: hidden=[128], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8098
#   Fold 2/10: AUROC = 0.8489
#   Fold 3/10: AUROC = 0.8601
#   Fold 4/10: AUROC = 0.9388
#   Fold 5/10: AUROC = 0.8718
#   Fold 6/10: AUROC = 0.9281
#   Fold 7/10: AUROC = 0.8737
#   Fold 8/10: AUROC = 0.9293
#   Fold 9/10: AUROC = 0.7392
#   Fold 10/10: AUROC = 0.8305
#   Mean AUROC: 0.8630 ± 0.0583
# Config 24/96: hidden=[128], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7934
#   Fold 2/10: AUROC = 0.8527
#   Fold 3/10: AUROC = 0.8658
#   Fold 4/10: AUROC = 0.9395
#   Fold 5/10: AUROC = 0.8783
#   Fold 6/10: AUROC = 0.9022
#   Fold 7/10: AUROC = 0.8575
#   Fold 8/10: AUROC = 0.9176
#   Fold 9/10: AUROC = 0.7823
#   Fold 10/10: AUROC = 0.8543
#   Mean AUROC: 0.8643 ± 0.0471
# Config 25/96: hidden=[128], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7990
#   Fold 2/10: AUROC = 0.8629
#   Fold 3/10: AUROC = 0.8574
#   Fold 4/10: AUROC = 0.9535
#   Fold 5/10: AUROC = 0.8768
#   Fold 6/10: AUROC = 0.8987
#   Fold 7/10: AUROC = 0.9220
#   Fold 8/10: AUROC = 0.9322
#   Fold 9/10: AUROC = 0.7172
#   Fold 10/10: AUROC = 0.8402
#   Mean AUROC: 0.8660 ± 0.0661
# Config 26/96: hidden=[128], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8013
#   Fold 2/10: AUROC = 0.8711
#   Fold 3/10: AUROC = 0.8552
#   Fold 4/10: AUROC = 0.9415
#   Fold 5/10: AUROC = 0.9047
#   Fold 6/10: AUROC = 0.8734
#   Fold 7/10: AUROC = 0.8836
#   Fold 8/10: AUROC = 0.9588
#   Fold 9/10: AUROC = 0.7175
#   Fold 10/10: AUROC = 0.8584
#   Mean AUROC: 0.8665 ± 0.0653
# Config 27/96: hidden=[128], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8180
#   Fold 2/10: AUROC = 0.8553
#   Fold 3/10: AUROC = 0.8133
#   Fold 4/10: AUROC = 0.9302
#   Fold 5/10: AUROC = 0.8810
#   Fold 6/10: AUROC = 0.8877
#   Fold 7/10: AUROC = 0.8770
#   Fold 8/10: AUROC = 0.9564
#   Fold 9/10: AUROC = 0.6632
#   Fold 10/10: AUROC = 0.8497
#   Mean AUROC: 0.8532 ± 0.0762
# Config 28/96: hidden=[128], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8354
#   Fold 2/10: AUROC = 0.8650
#   Fold 3/10: AUROC = 0.8117
#   Fold 4/10: AUROC = 0.9450
#   Fold 5/10: AUROC = 0.9131
#   Fold 6/10: AUROC = 0.8711
#   Fold 7/10: AUROC = 0.8750
#   Fold 8/10: AUROC = 0.9614
#   Fold 9/10: AUROC = 0.7414
#   Fold 10/10: AUROC = 0.8447
#   Mean AUROC: 0.8664 ± 0.0613
# Config 29/96: hidden=[128], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7955
#   Fold 2/10: AUROC = 0.8629
#   Fold 3/10: AUROC = 0.8456
#   Fold 4/10: AUROC = 0.9378
#   Fold 5/10: AUROC = 0.8865
#   Fold 6/10: AUROC = 0.9020
#   Fold 7/10: AUROC = 0.8918
#   Fold 8/10: AUROC = 0.9488
#   Fold 9/10: AUROC = 0.7516
#   Fold 10/10: AUROC = 0.8434
#   Mean AUROC: 0.8666 ± 0.0578
# Config 30/96: hidden=[128], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8023
#   Fold 2/10: AUROC = 0.8708
#   Fold 3/10: AUROC = 0.9018
#   Fold 4/10: AUROC = 0.9407
#   Fold 5/10: AUROC = 0.9054
#   Fold 6/10: AUROC = 0.8832
#   Fold 7/10: AUROC = 0.8900
#   Fold 8/10: AUROC = 0.9383
#   Fold 9/10: AUROC = 0.7745
#   Fold 10/10: AUROC = 0.8462
#   Mean AUROC: 0.8753 ± 0.0515
# Config 31/96: hidden=[128], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8295
#   Fold 2/10: AUROC = 0.8532
#   Fold 3/10: AUROC = 0.8779
#   Fold 4/10: AUROC = 0.9423
#   Fold 5/10: AUROC = 0.8902
#   Fold 6/10: AUROC = 0.8840
#   Fold 7/10: AUROC = 0.8509
#   Fold 8/10: AUROC = 0.9547
#   Fold 9/10: AUROC = 0.6976
#   Fold 10/10: AUROC = 0.8227
#   Mean AUROC: 0.8603 ± 0.0681
# Config 32/96: hidden=[128], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7980
#   Fold 2/10: AUROC = 0.8716
#   Fold 3/10: AUROC = 0.8576
#   Fold 4/10: AUROC = 0.9450
#   Fold 5/10: AUROC = 0.8925
#   Fold 6/10: AUROC = 0.9193
#   Fold 7/10: AUROC = 0.8927
#   Fold 8/10: AUROC = 0.9509
#   Fold 9/10: AUROC = 0.6882
#   Fold 10/10: AUROC = 0.8440
#   Mean AUROC: 0.8660 ± 0.0739
# Config 33/96: hidden=[256], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8240
#   Fold 2/10: AUROC = 0.8605
#   Fold 3/10: AUROC = 0.8811
#   Fold 4/10: AUROC = 0.9048
#   Fold 5/10: AUROC = 0.9017
#   Fold 6/10: AUROC = 0.9263
#   Fold 7/10: AUROC = 0.8662
#   Fold 8/10: AUROC = 0.9000
#   Fold 9/10: AUROC = 0.7075
#   Fold 10/10: AUROC = 0.8204
#   Mean AUROC: 0.8592 ± 0.0603
# Config 34/96: hidden=[256], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7967
#   Fold 2/10: AUROC = 0.8464
#   Fold 3/10: AUROC = 0.8705
#   Fold 4/10: AUROC = 0.9324
#   Fold 5/10: AUROC = 0.8912
#   Fold 6/10: AUROC = 0.9095
#   Fold 7/10: AUROC = 0.8558
#   Fold 8/10: AUROC = 0.9445
#   Fold 9/10: AUROC = 0.6989
#   Fold 10/10: AUROC = 0.8705
#   Mean AUROC: 0.8616 ± 0.0679
# Config 35/96: hidden=[256], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7965
#   Fold 2/10: AUROC = 0.8433
#   Fold 3/10: AUROC = 0.8476
#   Fold 4/10: AUROC = 0.9225
#   Fold 5/10: AUROC = 0.8758
#   Fold 6/10: AUROC = 0.9105
#   Fold 7/10: AUROC = 0.8660
#   Fold 8/10: AUROC = 0.9693
#   Fold 9/10: AUROC = 0.6844
#   Fold 10/10: AUROC = 0.8502
#   Mean AUROC: 0.8566 ± 0.0735
# Config 36/96: hidden=[256], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7861
#   Fold 2/10: AUROC = 0.8610
#   Fold 3/10: AUROC = 0.8456
#   Fold 4/10: AUROC = 0.9226
#   Fold 5/10: AUROC = 0.8935
#   Fold 6/10: AUROC = 0.8887
#   Fold 7/10: AUROC = 0.8467
#   Fold 8/10: AUROC = 0.9526
#   Fold 9/10: AUROC = 0.7266
#   Fold 10/10: AUROC = 0.8233
#   Mean AUROC: 0.8547 ± 0.0626
# Config 37/96: hidden=[256], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7753
#   Fold 2/10: AUROC = 0.8529
#   Fold 3/10: AUROC = 0.8319
#   Fold 4/10: AUROC = 0.9341
#   Fold 5/10: AUROC = 0.8793
#   Fold 6/10: AUROC = 0.8819
#   Fold 7/10: AUROC = 0.8257
#   Fold 8/10: AUROC = 0.9395
#   Fold 9/10: AUROC = 0.7210
#   Fold 10/10: AUROC = 0.8296
#   Mean AUROC: 0.8471 ± 0.0636
# Config 38/96: hidden=[256], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8172
#   Fold 2/10: AUROC = 0.8433
#   Fold 3/10: AUROC = 0.8350
#   Fold 4/10: AUROC = 0.9439
#   Fold 5/10: AUROC = 0.8959
#   Fold 6/10: AUROC = 0.9034
#   Fold 7/10: AUROC = 0.8964
#   Fold 8/10: AUROC = 0.9427
#   Fold 9/10: AUROC = 0.7823
#   Fold 10/10: AUROC = 0.8887
#   Mean AUROC: 0.8749 ± 0.0508
# Config 39/96: hidden=[256], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7914
#   Fold 2/10: AUROC = 0.8666
#   Fold 3/10: AUROC = 0.8172
#   Fold 4/10: AUROC = 0.9472
#   Fold 5/10: AUROC = 0.8875
#   Fold 6/10: AUROC = 0.9338
#   Fold 7/10: AUROC = 0.8783
#   Fold 8/10: AUROC = 0.9532
#   Fold 9/10: AUROC = 0.6425
#   Fold 10/10: AUROC = 0.8281
#   Mean AUROC: 0.8546 ± 0.0880
# Config 40/96: hidden=[256], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7770
#   Fold 2/10: AUROC = 0.8786
#   Fold 3/10: AUROC = 0.8772
#   Fold 4/10: AUROC = 0.9369
#   Fold 5/10: AUROC = 0.8875
#   Fold 6/10: AUROC = 0.8697
#   Fold 7/10: AUROC = 0.8765
#   Fold 8/10: AUROC = 0.9638
#   Fold 9/10: AUROC = 0.7242
#   Fold 10/10: AUROC = 0.8568
#   Mean AUROC: 0.8648 ± 0.0660
# Config 41/96: hidden=[256], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7959
#   Fold 2/10: AUROC = 0.8687
#   Fold 3/10: AUROC = 0.8456
#   Fold 4/10: AUROC = 0.9414
#   Fold 5/10: AUROC = 0.8750
#   Fold 6/10: AUROC = 0.9103
#   Fold 7/10: AUROC = 0.8852
#   Fold 8/10: AUROC = 0.9328
#   Fold 9/10: AUROC = 0.7315
#   Fold 10/10: AUROC = 0.8339
#   Mean AUROC: 0.8620 ± 0.0607
# Config 42/96: hidden=[256], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7848
#   Fold 2/10: AUROC = 0.8603
#   Fold 3/10: AUROC = 0.8358
#   Fold 4/10: AUROC = 0.9237
#   Fold 5/10: AUROC = 0.8882
#   Fold 6/10: AUROC = 0.9030
#   Fold 7/10: AUROC = 0.9187
#   Fold 8/10: AUROC = 0.9503
#   Fold 9/10: AUROC = 0.7898
#   Fold 10/10: AUROC = 0.8129
#   Mean AUROC: 0.8667 ± 0.0559
# Config 43/96: hidden=[256], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7866
#   Fold 2/10: AUROC = 0.8591
#   Fold 3/10: AUROC = 0.8438
#   Fold 4/10: AUROC = 0.9308
#   Fold 5/10: AUROC = 0.8730
#   Fold 6/10: AUROC = 0.8860
#   Fold 7/10: AUROC = 0.8660
#   Fold 8/10: AUROC = 0.9214
#   Fold 9/10: AUROC = 0.6694
#   Fold 10/10: AUROC = 0.8192
#   Mean AUROC: 0.8455 ± 0.0716
# Config 44/96: hidden=[256], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8197
#   Fold 2/10: AUROC = 0.8468
#   Fold 3/10: AUROC = 0.8313
#   Fold 4/10: AUROC = 0.9507
#   Fold 5/10: AUROC = 0.8755
#   Fold 6/10: AUROC = 0.9105
#   Fold 7/10: AUROC = 0.8465
#   Fold 8/10: AUROC = 0.9611
#   Fold 9/10: AUROC = 0.6858
#   Fold 10/10: AUROC = 0.8526
#   Mean AUROC: 0.8581 ± 0.0738
# Config 45/96: hidden=[256], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8149
#   Fold 2/10: AUROC = 0.8537
#   Fold 3/10: AUROC = 0.8922
#   Fold 4/10: AUROC = 0.9267
#   Fold 5/10: AUROC = 0.8825
#   Fold 6/10: AUROC = 0.8554
#   Fold 7/10: AUROC = 0.8971
#   Fold 8/10: AUROC = 0.9386
#   Fold 9/10: AUROC = 0.8145
#   Fold 10/10: AUROC = 0.8583
#   Mean AUROC: 0.8734 ± 0.0399
# Config 46/96: hidden=[256], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8094
#   Fold 2/10: AUROC = 0.8699
#   Fold 3/10: AUROC = 0.8632
#   Fold 4/10: AUROC = 0.9119
#   Fold 5/10: AUROC = 0.9024
#   Fold 6/10: AUROC = 0.9013
#   Fold 7/10: AUROC = 0.8810
#   Fold 8/10: AUROC = 0.9395
#   Fold 9/10: AUROC = 0.7831
#   Fold 10/10: AUROC = 0.8757
#   Mean AUROC: 0.8737 ± 0.0446
# Config 47/96: hidden=[256], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7851
#   Fold 2/10: AUROC = 0.8614
#   Fold 3/10: AUROC = 0.8403
#   Fold 4/10: AUROC = 0.9180
#   Fold 5/10: AUROC = 0.8905
#   Fold 6/10: AUROC = 0.9013
#   Fold 7/10: AUROC = 0.8675
#   Fold 8/10: AUROC = 0.9538
#   Fold 9/10: AUROC = 0.6935
#   Fold 10/10: AUROC = 0.8250
#   Mean AUROC: 0.8536 ± 0.0703
# Config 48/96: hidden=[256], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7690
#   Fold 2/10: AUROC = 0.8692
#   Fold 3/10: AUROC = 0.8546
#   Fold 4/10: AUROC = 0.9255
#   Fold 5/10: AUROC = 0.8895
#   Fold 6/10: AUROC = 0.9228
#   Fold 7/10: AUROC = 0.8838
#   Fold 8/10: AUROC = 0.9383
#   Fold 9/10: AUROC = 0.7449
#   Fold 10/10: AUROC = 0.8474
#   Mean AUROC: 0.8645 ± 0.0612
# Config 49/96: hidden=[64, 32], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8300
#   Fold 2/10: AUROC = 0.8682
#   Fold 3/10: AUROC = 0.8842
#   Fold 4/10: AUROC = 0.9554
#   Fold 5/10: AUROC = 0.9181
#   Fold 6/10: AUROC = 0.9138
#   Fold 7/10: AUROC = 0.8648
#   Fold 8/10: AUROC = 0.9287
#   Fold 9/10: AUROC = 0.7454
#   Fold 10/10: AUROC = 0.8318
#   Mean AUROC: 0.8740 ± 0.0580
# Config 50/96: hidden=[64, 32], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7785
#   Fold 2/10: AUROC = 0.8878
#   Fold 3/10: AUROC = 0.8176
#   Fold 4/10: AUROC = 0.9532
#   Fold 5/10: AUROC = 0.9154
#   Fold 6/10: AUROC = 0.9355
#   Fold 7/10: AUROC = 0.8527
#   Fold 8/10: AUROC = 0.9494
#   Fold 9/10: AUROC = 0.6599
#   Fold 10/10: AUROC = 0.8709
#   Mean AUROC: 0.8621 ± 0.0865
# Config 51/96: hidden=[64, 32], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8028
#   Fold 2/10: AUROC = 0.8762
#   Fold 3/10: AUROC = 0.8658
#   Fold 4/10: AUROC = 0.9285
#   Fold 5/10: AUROC = 0.9188
#   Fold 6/10: AUROC = 0.8772
#   Fold 7/10: AUROC = 0.8452
#   Fold 8/10: AUROC = 0.9465
#   Fold 9/10: AUROC = 0.7989
#   Fold 10/10: AUROC = 0.8444
#   Mean AUROC: 0.8704 ± 0.0475
# Config 52/96: hidden=[64, 32], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8215
#   Fold 2/10: AUROC = 0.8678
#   Fold 3/10: AUROC = 0.8256
#   Fold 4/10: AUROC = 0.9152
#   Fold 5/10: AUROC = 0.8825
#   Fold 6/10: AUROC = 0.9365
#   Fold 7/10: AUROC = 0.9227
#   Fold 8/10: AUROC = 0.9243
#   Fold 9/10: AUROC = 0.7640
#   Fold 10/10: AUROC = 0.8325
#   Mean AUROC: 0.8693 ± 0.0541
# Config 53/96: hidden=[64, 32], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7805
#   Fold 2/10: AUROC = 0.8720
#   Fold 3/10: AUROC = 0.8505
#   Fold 4/10: AUROC = 0.9485
#   Fold 5/10: AUROC = 0.8837
#   Fold 6/10: AUROC = 0.9177
#   Fold 7/10: AUROC = 0.8717
#   Fold 8/10: AUROC = 0.9310
#   Fold 9/10: AUROC = 0.8121
#   Fold 10/10: AUROC = 0.8522
#   Mean AUROC: 0.8720 ± 0.0494
# Config 54/96: hidden=[64, 32], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7811
#   Fold 2/10: AUROC = 0.8862
#   Fold 3/10: AUROC = 0.8785
#   Fold 4/10: AUROC = 0.9328
#   Fold 5/10: AUROC = 0.9074
#   Fold 6/10: AUROC = 0.8756
#   Fold 7/10: AUROC = 0.8591
#   Fold 8/10: AUROC = 0.9708
#   Fold 9/10: AUROC = 0.8159
#   Fold 10/10: AUROC = 0.8831
#   Mean AUROC: 0.8790 ± 0.0512
# Config 55/96: hidden=[64, 32], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8300
#   Fold 2/10: AUROC = 0.8690
#   Fold 3/10: AUROC = 0.8740
#   Fold 4/10: AUROC = 0.8954
#   Fold 5/10: AUROC = 0.9104
#   Fold 6/10: AUROC = 0.8983
#   Fold 7/10: AUROC = 0.8867
#   Fold 8/10: AUROC = 0.9649
#   Fold 9/10: AUROC = 0.7253
#   Fold 10/10: AUROC = 0.8748
#   Mean AUROC: 0.8729 ± 0.0591
# Config 56/96: hidden=[64, 32], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8015
#   Fold 2/10: AUROC = 0.8711
#   Fold 3/10: AUROC = 0.8550
#   Fold 4/10: AUROC = 0.9296
#   Fold 5/10: AUROC = 0.9086
#   Fold 6/10: AUROC = 0.8877
#   Fold 7/10: AUROC = 0.8679
#   Fold 8/10: AUROC = 0.9541
#   Fold 9/10: AUROC = 0.7089
#   Fold 10/10: AUROC = 0.8632
#   Mean AUROC: 0.8648 ± 0.0656
# Config 57/96: hidden=[64, 32], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7894
#   Fold 2/10: AUROC = 0.8258
#   Fold 3/10: AUROC = 0.8634
#   Fold 4/10: AUROC = 0.9330
#   Fold 5/10: AUROC = 0.9061
#   Fold 6/10: AUROC = 0.9030
#   Fold 7/10: AUROC = 0.8655
#   Fold 8/10: AUROC = 0.9225
#   Fold 9/10: AUROC = 0.7234
#   Fold 10/10: AUROC = 0.8325
#   Mean AUROC: 0.8565 ± 0.0622
# Config 58/96: hidden=[64, 32], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8146
#   Fold 2/10: AUROC = 0.8742
#   Fold 3/10: AUROC = 0.8391
#   Fold 4/10: AUROC = 0.9123
#   Fold 5/10: AUROC = 0.9009
#   Fold 6/10: AUROC = 0.9167
#   Fold 7/10: AUROC = 0.8814
#   Fold 8/10: AUROC = 0.9310
#   Fold 9/10: AUROC = 0.7543
#   Fold 10/10: AUROC = 0.8634
#   Mean AUROC: 0.8688 ± 0.0512
# Config 59/96: hidden=[64, 32], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7536
#   Fold 2/10: AUROC = 0.8110
#   Fold 3/10: AUROC = 0.7706
#   Fold 4/10: AUROC = 0.8799
#   Fold 5/10: AUROC = 0.9333
#   Fold 6/10: AUROC = 0.8615
#   Fold 7/10: AUROC = 0.8485
#   Fold 8/10: AUROC = 0.9293
#   Fold 9/10: AUROC = 0.6903
#   Fold 10/10: AUROC = 0.8119
#   Mean AUROC: 0.8290 ± 0.0734
# Config 60/96: hidden=[64, 32], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8068
#   Fold 2/10: AUROC = 0.8331
#   Fold 3/10: AUROC = 0.8252
#   Fold 4/10: AUROC = 0.8937
#   Fold 5/10: AUROC = 0.8793
#   Fold 6/10: AUROC = 0.9152
#   Fold 7/10: AUROC = 0.8445
#   Fold 8/10: AUROC = 0.9512
#   Fold 9/10: AUROC = 0.6470
#   Fold 10/10: AUROC = 0.8412
#   Mean AUROC: 0.8437 ± 0.0781
# Config 61/96: hidden=[64, 32], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7922
#   Fold 2/10: AUROC = 0.8720
#   Fold 3/10: AUROC = 0.8580
#   Fold 4/10: AUROC = 0.9559
#   Fold 5/10: AUROC = 0.9183
#   Fold 6/10: AUROC = 0.9114
#   Fold 7/10: AUROC = 0.8988
#   Fold 8/10: AUROC = 0.9676
#   Fold 9/10: AUROC = 0.7858
#   Fold 10/10: AUROC = 0.8820
#   Mean AUROC: 0.8842 ± 0.0576
# Config 62/96: hidden=[64, 32], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8255
#   Fold 2/10: AUROC = 0.8756
#   Fold 3/10: AUROC = 0.8552
#   Fold 4/10: AUROC = 0.9481
#   Fold 5/10: AUROC = 0.8979
#   Fold 6/10: AUROC = 0.9083
#   Fold 7/10: AUROC = 0.8383
#   Fold 8/10: AUROC = 0.9629
#   Fold 9/10: AUROC = 0.7492
#   Fold 10/10: AUROC = 0.8969
#   Mean AUROC: 0.8758 ± 0.0593
# Config 63/96: hidden=[64, 32], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7987
#   Fold 2/10: AUROC = 0.8619
#   Fold 3/10: AUROC = 0.8589
#   Fold 4/10: AUROC = 0.9487
#   Fold 5/10: AUROC = 0.9039
#   Fold 6/10: AUROC = 0.9065
#   Fold 7/10: AUROC = 0.8525
#   Fold 8/10: AUROC = 0.9006
#   Fold 9/10: AUROC = 0.7478
#   Fold 10/10: AUROC = 0.8376
#   Mean AUROC: 0.8617 ± 0.0552
# Config 64/96: hidden=[64, 32], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8142
#   Fold 2/10: AUROC = 0.8635
#   Fold 3/10: AUROC = 0.8478
#   Fold 4/10: AUROC = 0.9373
#   Fold 5/10: AUROC = 0.9017
#   Fold 6/10: AUROC = 0.9067
#   Fold 7/10: AUROC = 0.8600
#   Fold 8/10: AUROC = 0.9132
#   Fold 9/10: AUROC = 0.7831
#   Fold 10/10: AUROC = 0.8917
#   Mean AUROC: 0.8719 ± 0.0453
# Config 65/96: hidden=[128, 64], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7603
#   Fold 2/10: AUROC = 0.8650
#   Fold 3/10: AUROC = 0.8697
#   Fold 4/10: AUROC = 0.9507
#   Fold 5/10: AUROC = 0.8930
#   Fold 6/10: AUROC = 0.9150
#   Fold 7/10: AUROC = 0.8728
#   Fold 8/10: AUROC = 0.9547
#   Fold 9/10: AUROC = 0.6801
#   Fold 10/10: AUROC = 0.8616
#   Mean AUROC: 0.8623 ± 0.0799
# Config 66/96: hidden=[128, 64], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7940
#   Fold 2/10: AUROC = 0.8598
#   Fold 3/10: AUROC = 0.8405
#   Fold 4/10: AUROC = 0.9312
#   Fold 5/10: AUROC = 0.8962
#   Fold 6/10: AUROC = 0.9126
#   Fold 7/10: AUROC = 0.8969
#   Fold 8/10: AUROC = 0.9579
#   Fold 9/10: AUROC = 0.7140
#   Fold 10/10: AUROC = 0.8627
#   Mean AUROC: 0.8666 ± 0.0676
# Config 67/96: hidden=[128, 64], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7993
#   Fold 2/10: AUROC = 0.8244
#   Fold 3/10: AUROC = 0.8589
#   Fold 4/10: AUROC = 0.9319
#   Fold 5/10: AUROC = 0.8999
#   Fold 6/10: AUROC = 0.8973
#   Fold 7/10: AUROC = 0.9008
#   Fold 8/10: AUROC = 0.8930
#   Fold 9/10: AUROC = 0.7234
#   Fold 10/10: AUROC = 0.8182
#   Mean AUROC: 0.8547 ± 0.0600
# Config 68/96: hidden=[128, 64], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8002
#   Fold 2/10: AUROC = 0.8657
#   Fold 3/10: AUROC = 0.8364
#   Fold 4/10: AUROC = 0.9511
#   Fold 5/10: AUROC = 0.9124
#   Fold 6/10: AUROC = 0.9277
#   Fold 7/10: AUROC = 0.8401
#   Fold 8/10: AUROC = 0.9515
#   Fold 9/10: AUROC = 0.7382
#   Fold 10/10: AUROC = 0.8267
#   Mean AUROC: 0.8650 ± 0.0665
# Config 69/96: hidden=[128, 64], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8144
#   Fold 2/10: AUROC = 0.8675
#   Fold 3/10: AUROC = 0.8438
#   Fold 4/10: AUROC = 0.9466
#   Fold 5/10: AUROC = 0.8872
#   Fold 6/10: AUROC = 0.9269
#   Fold 7/10: AUROC = 0.8730
#   Fold 8/10: AUROC = 0.9363
#   Fold 9/10: AUROC = 0.7605
#   Fold 10/10: AUROC = 0.8685
#   Mean AUROC: 0.8725 ± 0.0543
# Config 70/96: hidden=[128, 64], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8022
#   Fold 2/10: AUROC = 0.8876
#   Fold 3/10: AUROC = 0.8752
#   Fold 4/10: AUROC = 0.9290
#   Fold 5/10: AUROC = 0.8999
#   Fold 6/10: AUROC = 0.8830
#   Fold 7/10: AUROC = 0.8776
#   Fold 8/10: AUROC = 0.9369
#   Fold 9/10: AUROC = 0.7677
#   Fold 10/10: AUROC = 0.8949
#   Mean AUROC: 0.8754 ± 0.0498
# Config 71/96: hidden=[128, 64], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8126
#   Fold 2/10: AUROC = 0.8371
#   Fold 3/10: AUROC = 0.7845
#   Fold 4/10: AUROC = 0.9383
#   Fold 5/10: AUROC = 0.9213
#   Fold 6/10: AUROC = 0.9242
#   Fold 7/10: AUROC = 0.8702
#   Fold 8/10: AUROC = 0.9491
#   Fold 9/10: AUROC = 0.7196
#   Fold 10/10: AUROC = 0.8594
#   Mean AUROC: 0.8617 ± 0.0709
# Config 72/96: hidden=[128, 64], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8046
#   Fold 2/10: AUROC = 0.8645
#   Fold 3/10: AUROC = 0.8721
#   Fold 4/10: AUROC = 0.9408
#   Fold 5/10: AUROC = 0.8984
#   Fold 6/10: AUROC = 0.9034
#   Fold 7/10: AUROC = 0.8867
#   Fold 8/10: AUROC = 0.9436
#   Fold 9/10: AUROC = 0.7524
#   Fold 10/10: AUROC = 0.8773
#   Mean AUROC: 0.8744 ± 0.0553
# Config 73/96: hidden=[128, 64], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8156
#   Fold 2/10: AUROC = 0.8565
#   Fold 3/10: AUROC = 0.8644
#   Fold 4/10: AUROC = 0.9513
#   Fold 5/10: AUROC = 0.9101
#   Fold 6/10: AUROC = 0.9312
#   Fold 7/10: AUROC = 0.8832
#   Fold 8/10: AUROC = 0.9462
#   Fold 9/10: AUROC = 0.7511
#   Fold 10/10: AUROC = 0.8470
#   Mean AUROC: 0.8757 ± 0.0596
# Config 74/96: hidden=[128, 64], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7919
#   Fold 2/10: AUROC = 0.8807
#   Fold 3/10: AUROC = 0.8317
#   Fold 4/10: AUROC = 0.9519
#   Fold 5/10: AUROC = 0.9467
#   Fold 6/10: AUROC = 0.9267
#   Fold 7/10: AUROC = 0.8626
#   Fold 8/10: AUROC = 0.9483
#   Fold 9/10: AUROC = 0.7406
#   Fold 10/10: AUROC = 0.8349
#   Mean AUROC: 0.8716 ± 0.0690
# Config 75/96: hidden=[128, 64], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8363
#   Fold 2/10: AUROC = 0.8346
#   Fold 3/10: AUROC = 0.8313
#   Fold 4/10: AUROC = 0.9344
#   Fold 5/10: AUROC = 0.8994
#   Fold 6/10: AUROC = 0.8969
#   Fold 7/10: AUROC = 0.8761
#   Fold 8/10: AUROC = 0.9491
#   Fold 9/10: AUROC = 0.7245
#   Fold 10/10: AUROC = 0.8546
#   Mean AUROC: 0.8637 ± 0.0608
# Config 76/96: hidden=[128, 64], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7848
#   Fold 2/10: AUROC = 0.7824
#   Fold 3/10: AUROC = 0.8182
#   Fold 4/10: AUROC = 0.9360
#   Fold 5/10: AUROC = 0.9251
#   Fold 6/10: AUROC = 0.8981
#   Fold 7/10: AUROC = 0.8741
#   Fold 8/10: AUROC = 0.9509
#   Fold 9/10: AUROC = 0.6720
#   Fold 10/10: AUROC = 0.8591
#   Mean AUROC: 0.8501 ± 0.0823
# Config 77/96: hidden=[128, 64], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7992
#   Fold 2/10: AUROC = 0.8795
#   Fold 3/10: AUROC = 0.8719
#   Fold 4/10: AUROC = 0.9402
#   Fold 5/10: AUROC = 0.8984
#   Fold 6/10: AUROC = 0.9016
#   Fold 7/10: AUROC = 0.8779
#   Fold 8/10: AUROC = 0.9418
#   Fold 9/10: AUROC = 0.7535
#   Fold 10/10: AUROC = 0.8805
#   Mean AUROC: 0.8744 ± 0.0553
# Config 78/96: hidden=[128, 64], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7921
#   Fold 2/10: AUROC = 0.8598
#   Fold 3/10: AUROC = 0.8619
#   Fold 4/10: AUROC = 0.9503
#   Fold 5/10: AUROC = 0.9101
#   Fold 6/10: AUROC = 0.9050
#   Fold 7/10: AUROC = 0.8792
#   Fold 8/10: AUROC = 0.9579
#   Fold 9/10: AUROC = 0.7858
#   Fold 10/10: AUROC = 0.8881
#   Mean AUROC: 0.8790 ± 0.0547
# Config 79/96: hidden=[128, 64], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7856
#   Fold 2/10: AUROC = 0.8770
#   Fold 3/10: AUROC = 0.8713
#   Fold 4/10: AUROC = 0.9255
#   Fold 5/10: AUROC = 0.9066
#   Fold 6/10: AUROC = 0.9189
#   Fold 7/10: AUROC = 0.8878
#   Fold 8/10: AUROC = 0.9307
#   Fold 9/10: AUROC = 0.7435
#   Fold 10/10: AUROC = 0.8583
#   Mean AUROC: 0.8705 ± 0.0584
# Config 80/96: hidden=[128, 64], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7912
#   Fold 2/10: AUROC = 0.8845
#   Fold 3/10: AUROC = 0.8632
#   Fold 4/10: AUROC = 0.9421
#   Fold 5/10: AUROC = 0.8872
#   Fold 6/10: AUROC = 0.9389
#   Fold 7/10: AUROC = 0.8719
#   Fold 8/10: AUROC = 0.9474
#   Fold 9/10: AUROC = 0.8239
#   Fold 10/10: AUROC = 0.8632
#   Mean AUROC: 0.8814 ± 0.0486
# Config 81/96: hidden=[256, 128], dropout=0.6, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7858
#   Fold 2/10: AUROC = 0.8735
#   Fold 3/10: AUROC = 0.8417
#   Fold 4/10: AUROC = 0.9222
#   Fold 5/10: AUROC = 0.9178
#   Fold 6/10: AUROC = 0.9248
#   Fold 7/10: AUROC = 0.8878
#   Fold 8/10: AUROC = 0.9117
#   Fold 9/10: AUROC = 0.7113
#   Fold 10/10: AUROC = 0.8460
#   Mean AUROC: 0.8623 ± 0.0657
# Config 82/96: hidden=[256, 128], dropout=0.6, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7833
#   Fold 2/10: AUROC = 0.8385
#   Fold 3/10: AUROC = 0.8521
#   Fold 4/10: AUROC = 0.9542
#   Fold 5/10: AUROC = 0.9174
#   Fold 6/10: AUROC = 0.8999
#   Fold 7/10: AUROC = 0.8827
#   Fold 8/10: AUROC = 0.9354
#   Fold 9/10: AUROC = 0.7253
#   Fold 10/10: AUROC = 0.8368
#   Mean AUROC: 0.8625 ± 0.0671
# Config 83/96: hidden=[256, 128], dropout=0.6, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7694
#   Fold 2/10: AUROC = 0.7907
#   Fold 3/10: AUROC = 0.7966
#   Fold 4/10: AUROC = 0.9314
#   Fold 5/10: AUROC = 0.8922
#   Fold 6/10: AUROC = 0.8789
#   Fold 7/10: AUROC = 0.8878
#   Fold 8/10: AUROC = 0.9605
#   Fold 9/10: AUROC = 0.7013
#   Fold 10/10: AUROC = 0.8224
#   Mean AUROC: 0.8431 ± 0.0763
# Config 84/96: hidden=[256, 128], dropout=0.6, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7773
#   Fold 2/10: AUROC = 0.8491
#   Fold 3/10: AUROC = 0.8346
#   Fold 4/10: AUROC = 0.9440
#   Fold 5/10: AUROC = 0.9183
#   Fold 6/10: AUROC = 0.9167
#   Fold 7/10: AUROC = 0.8629
#   Fold 8/10: AUROC = 0.9366
#   Fold 9/10: AUROC = 0.6758
#   Fold 10/10: AUROC = 0.8467
#   Mean AUROC: 0.8562 ± 0.0782
# Config 85/96: hidden=[256, 128], dropout=0.6, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8099
#   Fold 2/10: AUROC = 0.8838
#   Fold 3/10: AUROC = 0.8754
#   Fold 4/10: AUROC = 0.9485
#   Fold 5/10: AUROC = 0.8813
#   Fold 6/10: AUROC = 0.9062
#   Fold 7/10: AUROC = 0.8684
#   Fold 8/10: AUROC = 0.9410
#   Fold 9/10: AUROC = 0.7188
#   Fold 10/10: AUROC = 0.8407
#   Mean AUROC: 0.8674 ± 0.0633
# Config 86/96: hidden=[256, 128], dropout=0.6, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8084
#   Fold 2/10: AUROC = 0.8449
#   Fold 3/10: AUROC = 0.8740
#   Fold 4/10: AUROC = 0.9369
#   Fold 5/10: AUROC = 0.8892
#   Fold 6/10: AUROC = 0.9214
#   Fold 7/10: AUROC = 0.8838
#   Fold 8/10: AUROC = 0.9500
#   Fold 9/10: AUROC = 0.7922
#   Fold 10/10: AUROC = 0.8719
#   Mean AUROC: 0.8773 ± 0.0490
# Config 87/96: hidden=[256, 128], dropout=0.6, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.7868
#   Fold 2/10: AUROC = 0.8430
#   Fold 3/10: AUROC = 0.8542
#   Fold 4/10: AUROC = 0.9280
#   Fold 5/10: AUROC = 0.9047
#   Fold 6/10: AUROC = 0.9175
#   Fold 7/10: AUROC = 0.9046
#   Fold 8/10: AUROC = 0.9412
#   Fold 9/10: AUROC = 0.7398
#   Fold 10/10: AUROC = 0.8661
#   Mean AUROC: 0.8686 ± 0.0616
# Config 88/96: hidden=[256, 128], dropout=0.6, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8033
#   Fold 2/10: AUROC = 0.8319
#   Fold 3/10: AUROC = 0.8221
#   Fold 4/10: AUROC = 0.9330
#   Fold 5/10: AUROC = 0.9034
#   Fold 6/10: AUROC = 0.9126
#   Fold 7/10: AUROC = 0.9030
#   Fold 8/10: AUROC = 0.9515
#   Fold 9/10: AUROC = 0.7183
#   Fold 10/10: AUROC = 0.8725
#   Mean AUROC: 0.8651 ± 0.0675
# Config 89/96: hidden=[256, 128], dropout=0.7, lr=0.001, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.8156
#   Fold 2/10: AUROC = 0.8537
#   Fold 3/10: AUROC = 0.8487
#   Fold 4/10: AUROC = 0.9616
#   Fold 5/10: AUROC = 0.8952
#   Fold 6/10: AUROC = 0.9009
#   Fold 7/10: AUROC = 0.9143
#   Fold 8/10: AUROC = 0.9535
#   Fold 9/10: AUROC = 0.7946
#   Fold 10/10: AUROC = 0.8629
#   Mean AUROC: 0.8801 ± 0.0523
# Config 90/96: hidden=[256, 128], dropout=0.7, lr=0.001, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.7925
#   Fold 2/10: AUROC = 0.8600
#   Fold 3/10: AUROC = 0.8556
#   Fold 4/10: AUROC = 0.9404
#   Fold 5/10: AUROC = 0.8673
#   Fold 6/10: AUROC = 0.8950
#   Fold 7/10: AUROC = 0.8562
#   Fold 8/10: AUROC = 0.9532
#   Fold 9/10: AUROC = 0.6997
#   Fold 10/10: AUROC = 0.8535
#   Mean AUROC: 0.8573 ± 0.0683
# Config 91/96: hidden=[256, 128], dropout=0.7, lr=0.001, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8353
#   Fold 2/10: AUROC = 0.8527
#   Fold 3/10: AUROC = 0.8223
#   Fold 4/10: AUROC = 0.9354
#   Fold 5/10: AUROC = 0.9064
#   Fold 6/10: AUROC = 0.9018
#   Fold 7/10: AUROC = 0.9194
#   Fold 8/10: AUROC = 0.9217
#   Fold 9/10: AUROC = 0.6683
#   Fold 10/10: AUROC = 0.8560
#   Mean AUROC: 0.8619 ± 0.0747
# Config 92/96: hidden=[256, 128], dropout=0.7, lr=0.001, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.7970
#   Fold 2/10: AUROC = 0.8854
#   Fold 3/10: AUROC = 0.8358
#   Fold 4/10: AUROC = 0.9392
#   Fold 5/10: AUROC = 0.8907
#   Fold 6/10: AUROC = 0.9048
#   Fold 7/10: AUROC = 0.8436
#   Fold 8/10: AUROC = 0.9328
#   Fold 9/10: AUROC = 0.7315
#   Fold 10/10: AUROC = 0.8328
#   Mean AUROC: 0.8593 ± 0.0610
# Config 93/96: hidden=[256, 128], dropout=0.7, lr=0.005, batch=64, wd=0.0001
#   Fold 1/10: AUROC = 0.7959
#   Fold 2/10: AUROC = 0.8942
#   Fold 3/10: AUROC = 0.8681
#   Fold 4/10: AUROC = 0.9447
#   Fold 5/10: AUROC = 0.9039
#   Fold 6/10: AUROC = 0.8987
#   Fold 7/10: AUROC = 0.8893
#   Fold 8/10: AUROC = 0.9462
#   Fold 9/10: AUROC = 0.7379
#   Fold 10/10: AUROC = 0.8823
#   Mean AUROC: 0.8761 ± 0.0609
# Config 94/96: hidden=[256, 128], dropout=0.7, lr=0.005, batch=64, wd=0.001
#   Fold 1/10: AUROC = 0.8205
#   Fold 2/10: AUROC = 0.8458
#   Fold 3/10: AUROC = 0.8313
#   Fold 4/10: AUROC = 0.9590
#   Fold 5/10: AUROC = 0.8972
#   Fold 6/10: AUROC = 0.9058
#   Fold 7/10: AUROC = 0.8929
#   Fold 8/10: AUROC = 0.9497
#   Fold 9/10: AUROC = 0.8457
#   Fold 10/10: AUROC = 0.8742
#   Mean AUROC: 0.8822 ± 0.0452
# Config 95/96: hidden=[256, 128], dropout=0.7, lr=0.005, batch=128, wd=0.0001
#   Fold 1/10: AUROC = 0.8033
#   Fold 2/10: AUROC = 0.8310
#   Fold 3/10: AUROC = 0.8572
#   Fold 4/10: AUROC = 0.9404
#   Fold 5/10: AUROC = 0.8768
#   Fold 6/10: AUROC = 0.9132
#   Fold 7/10: AUROC = 0.8692
#   Fold 8/10: AUROC = 0.9518
#   Fold 9/10: AUROC = 0.8070
#   Fold 10/10: AUROC = 0.8631
#   Mean AUROC: 0.8713 ± 0.0487
# Config 96/96: hidden=[256, 128], dropout=0.7, lr=0.005, batch=128, wd=0.001
#   Fold 1/10: AUROC = 0.8083
#   Fold 2/10: AUROC = 0.8729
#   Fold 3/10: AUROC = 0.8460
#   Fold 4/10: AUROC = 0.9315
#   Fold 5/10: AUROC = 0.9096
#   Fold 6/10: AUROC = 0.9138
#   Fold 7/10: AUROC = 0.8774
#   Fold 8/10: AUROC = 0.9009
#   Fold 9/10: AUROC = 0.7887
#   Fold 10/10: AUROC = 0.8720
#   Mean AUROC: 0.8721 ± 0.0439
#
# Top 5 Hyperparameter Configurations:
#    hidden_dims  dropout  learning_rate  batch_size  weight_decay  mean_auroc  \
# 60    [64, 32]      0.7          0.005          64        0.0001    0.884191
# 93  [256, 128]      0.7          0.005          64        0.0010    0.882210
# 79   [128, 64]      0.7          0.005         128        0.0010    0.881360
# 9         [64]      0.7          0.001          64        0.0010    0.880344
# 88  [256, 128]      0.7          0.001          64        0.0001    0.880106
#
#     std_auroc
# 60   0.057620
# 93   0.045249
# 79   0.048562
# 9    0.049512
# 88   0.052265
#
# Best Configuration:
# Hidden Dimensions: [64, 32]
# Dropout Rate: 0.7
# Learning Rate: 0.005
# Batch Size: 64
# Weight Decay: 0.0001
# Mean AUROC: 0.8842

# %%
def train_final_model(X_train, y_train, best_params):
    # Convert DataFrames to numpy arrays if needed
    if hasattr(X_train, 'values'):
        X_train = X_train.values
    if hasattr(y_train, 'values'):
        y_train = y_train.values
    
    # Setup device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Convert to tensors
    X_tensor = torch.FloatTensor(X_train)
    y_tensor = torch.FloatTensor(y_train)
    
    # Create dataset and dataloader
    train_dataset = TensorDataset(X_tensor, y_tensor)
    train_loader = DataLoader(
        train_dataset, 
        batch_size=best_params['batch_size'], 
        shuffle=True
    )
    
    # Create model with best parameters
    model = BinaryClassifier(
        input_dim=X_train.shape[1],
        hidden_dims=best_params['hidden_dims'],
        dropout_rate=best_params['dropout_rate']
    )
    
    # Setup loss function and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=best_params['learning_rate'],
        weight_decay=best_params['weight_decay']
    )
    
    # Training
    model.to(device)
    model.train()
    
    # Training loop
    n_epochs = 150  # You can adjust this
    best_loss = float('inf')
    best_model_state = model.state_dict().copy()
    patience = 10
    epochs_no_improve = 0
    
    print("Training final model on entire dataset...")
    for epoch in range(n_epochs):
        running_loss = 0.0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Zero gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels.float())
            
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        # Calculate average loss for the epoch
        epoch_loss = running_loss / len(train_loader)
        
        # Print progress
        if (epoch+1) % 5 == 0:
            print(f"Epoch {epoch+1}/{n_epochs}, Loss: {epoch_loss:.6f}")
        
        # Early stopping
        if epoch_loss < best_loss:
            best_loss = epoch_loss
            best_model_state = model.state_dict().copy()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after epoch {epoch+1}")
                break
    
    # Load the best model
    model.load_state_dict(best_model_state)
    print(f"Training complete. Final loss: {best_loss:.6f}")
    
    return model

# Best configuration from cross-validation
best_params = {
    'hidden_dims': [64, 32],
    'dropout_rate': 0.7,
    'learning_rate': 0.005,
    'batch_size': 64,
    'weight_decay': 0.0001
}

# Train final model on entire training set
final_model = train_final_model(X_train, y_train, best_params)

# Save the trained model
torch.save(final_model.state_dict(), 'best_model.pt')
print("Model saved to 'best_model.pt'")
# Out:
# Using device: cuda:0
# Training final model on entire dataset...
# Epoch 5/150, Loss: 0.196514
# Epoch 10/150, Loss: 0.168291
# Epoch 15/150, Loss: 0.158798
# Epoch 20/150, Loss: 0.139720
# Epoch 25/150, Loss: 0.142175
# Epoch 30/150, Loss: 0.126438
# Epoch 35/150, Loss: 0.126034
# Epoch 40/150, Loss: 0.129675
# Epoch 45/150, Loss: 0.124957
# Early stopping triggered after epoch 46
# Training complete. Final loss: 0.122751
# Model saved to 'best_model.pt'

# %%
def results(pred_probas):
    OMI_score = np.round(pred_probas[:, 1]*100, decimals=2)
    y_pred = np.where(OMI_score<5, 'Low risk', 'Intermediate risk')
    y_pred = np.where(OMI_score>=20, 'High risk', y_pred)
    
    results = {
        'Low risk': [np.count_nonzero(y_pred == 'Low risk')],
        'Intermediate risk': [np.count_nonzero(y_pred == 'Intermediate risk')],
        'High risk': [np.count_nonzero(y_pred == 'High risk')]
    }
    return(pd.DataFrame(data=results, index=['Count (N)']))

# %%
# Predict on training data with the neural network
def predict_proba_nn(model, X):
    # Convert to numpy if DataFrame
    if hasattr(X, 'values'):
        X = X.values
        
    # Convert to tensor
    device = next(model.parameters()).device
    X_tensor = torch.FloatTensor(X).to(device)
    
    # Create dataloader
    dataset = TensorDataset(X_tensor)
    dataloader = DataLoader(dataset, batch_size=64)
    
    # Make predictions
    model.eval()
    predictions = []
    
    with torch.no_grad():
        for inputs in dataloader:
            inputs = inputs[0].to(device)
            outputs = model(inputs)
            probs = torch.sigmoid(outputs).cpu().numpy().flatten()
            predictions.extend(probs)
    
    # Convert to the same format as GBM output (two columns: [1-p, p])
    probs_array = np.column_stack((1 - np.array(predictions), np.array(predictions)))
    return probs_array

# Predict on training data
pred_probas_train = predict_proba_nn(final_model, X_train)
risk_groups_train = results(pred_probas_train)

# Compute ROC curve and area under the curve
fpr, tpr, thresholds = roc_curve(y_train, pred_probas_train[:,1])
roc_auc = auc(fpr, tpr)
plot_PyTorch_ROC_curve(fpr, tpr, roc_auc, 'Training curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_train, auroc_ci_upper_train = bootstrap_metric_ci(y_train, pred_probas_train[:,1], "auroc")
print(f"Training AUROC: {roc_auc:.3f} (95% CI: {auroc_ci_lower_train:.3f}, {auroc_ci_upper_train:.3f})")
# Out:
# Training AUROC: 0.979 (95% CI: 0.971, 0.986)

# %%
# Evaluate on validation set
print("\nVal")
pred_probas_val = predict_proba_nn(final_model, X_test)

# Compute ROC curve and area under the curve for validation set
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, pred_probas_val[:,1])
roc_auc_test = auc(fpr_test, tpr_test)
plot_PyTorch_ROC_curve(fpr_test, tpr_test, roc_auc_test, 'Validation curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_test, auroc_ci_upper_test = bootstrap_metric_ci(y_test, pred_probas_val[:,1], "auroc")
print(f"Val AUROC: {roc_auc_test:.3f} (95% CI: {auroc_ci_lower_test:.3f}, {auroc_ci_upper_test:.3f})")
# Out:
# Val
# Val AUROC: 0.928 (95% CI: 0.875, 0.967)

# %%
# Evaluate on test set
print("\nTest")
pred_probas_test = predict_proba_nn(final_model, X_val)

# Compute ROC curve and area under the curve for test set
fpr_test, tpr_test, thresholds_test = roc_curve(y_val, pred_probas_test[:,1])
roc_auc_test = auc(fpr_test, tpr_test)
plot_PyTorch_ROC_curve(fpr_test, tpr_test, roc_auc_test, 'Testing curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_test, auroc_ci_upper_test = bootstrap_metric_ci(y_val, pred_probas_test[:,1], "auroc")
print(f"Test AUROC: {roc_auc_test:.3f} (95% CI: {auroc_ci_lower_test:.3f}, {auroc_ci_upper_test:.3f})")
# Out:
# Test
# Test AUROC: 0.477 (95% CI: 0.462, 0.493)
