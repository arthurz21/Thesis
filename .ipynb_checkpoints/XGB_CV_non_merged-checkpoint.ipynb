# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import shap
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import precision_score, recall_score, f1_score
from copy import deepcopy
from math import sqrt
from sklearn.utils import resample
from itertools import product

# %%
derivation_cohort = pd.read_csv("Derivation_dataset.csv")
external_validation_cohort = pd.read_csv("External_validation_dataset.csv")

# %%
derivation_cohort.head()
# Out:
#    Outcome_Occlusion_MI   Age     HR     PR   QRSd  mfpQRSaxis  fpTaxis  \
# 0                     0  78.0  116.0   94.0  107.0         7.0    107.0
# 1                     0  84.0   71.0  174.0  136.0        53.0      NaN
# 2                     0  76.0   73.0  191.0  110.0       -72.0     56.0
# 3                     0  53.0   76.0  134.0   97.0        71.0     58.0
# 4                     0  34.0   76.0  160.0   87.0        43.0     70.0
#
#    txzQRSaxis  QRSTangle  mQRSTangle  ...  tamp_III  tamp_aVR  tamp_aVL  \
# 0        79.0      163.0       142.0  ...      46.0       0.0     -61.0
# 1        51.0      137.0       113.0  ...      69.0      51.0      32.0
# 2       110.0      153.0       147.0  ...      50.0    -131.0      29.0
# 3       117.0       50.0        78.0  ...     195.0    -249.0     -38.0
# 4        26.0       45.0        38.0  ...     169.0    -150.0     -59.0
#
#    tamp_aVF  tamp_V1  tamp_V2  tamp_V3  tamp_V4  tamp_V5  tamp_V6
# 0      63.0    132.0    201.0    319.0    125.0     59.0    -65.0
# 1     -72.0    344.0    742.0    668.0    172.0   -153.0     23.0
# 2     103.0    -50.0     81.0    186.0    155.0    101.0     60.0
# 3     266.0   -101.0     89.0    450.0    545.0    656.0    272.0
# 4     199.0     75.0    192.0    128.0    103.0    127.0    150.0
#
# [5 rows x 75 columns]

# %%
external_validation_cohort.head()
# Out:
#    Outcome_Occlusion_MI  Age   HR     PR  QRSd  mfpQRSaxis  fpTaxis  \
# 0                     0   64   98    NaN   128          35     14.0
# 1                     1   64   76  166.0    95           3     98.0
# 2                     0   55   65    NaN   125         -77     63.0
# 3                     0   58   67  248.0    79          79     44.0
# 4                     0   40  111  140.0   103          54    -22.0
#
#    txzQRSaxis  QRSTangle  mQRSTangle  ...  tamp_III  tamp_aVR  tamp_aVL  \
# 0        -108       23.0        82.0  ...      -105      -176       151
# 1         111       56.0        83.0  ...       136        77      -129
# 2          76      137.0       134.0  ...       138      -166        21
# 3          28       32.0        38.0  ...        48      -102       -22
# 4        -179       27.0        17.0  ...      -108       -51       112
#
#    tamp_aVF  tamp_V1  tamp_V2  tamp_V3  tamp_V4  tamp_V5  tamp_V6
# 0        80     -242     -129      -98      272      307      270
# 1       143      198      386      469     -147     -140     -106
# 2       186     -159      178      186      144      107       85
# 3        84      -33       89      205      179      115       58
# 4        -8      -53       29       87      129      -77      -62
#
# [5 rows x 75 columns]

# %%
y = derivation_cohort['Outcome_Occlusion_MI']
X = derivation_cohort.drop('Outcome_Occlusion_MI', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, random_state = 99)

y_val = external_validation_cohort['Outcome_Occlusion_MI']
X_val = external_validation_cohort.drop('Outcome_Occlusion_MI', axis=1)

for el in X_train.columns:
    X_train[el].fillna(X_train[el].mode()[0], inplace=True)
    X_test[el].fillna(X_train[el].mode()[0], inplace=True)
    X_val[el].fillna(X_train[el].mode()[0], inplace=True)

y_train = np.ravel(np.array(y_train.values))
y_test = np.ravel(np.array(y_test.values))
y_val = np.ravel(np.array(y_val.values))

columns = X_train.columns

X_train = np.array(X_train.values)
X_test = np.array(X_test.values)
X_val = np.array(X_val.values)

scaler = preprocessing.StandardScaler().fit(X_train) # Compute mean and std of training set
X_train = scaler.transform(X_train, copy=True)
X_test = scaler.transform(X_test, copy=True) # Standardize X_test using training mean and std
X_val = scaler.transform(X_val, copy=True)
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_92344\3933838254.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_92344\3933838254.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_92344\3933838254.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_val[el].fillna(X_train[el].mode()[0], inplace=True)

# %%
def get_xgb_classifier(params=None, calibrate=False, cv=5):
    """
    Returns an XGBClassifier with default or custom parameters.
    
    Args:
        params (dict): Dictionary of parameters to override defaults.
        calibrate (bool): Whether to apply isotonic calibration.
        cv (int): Number of cross-validation folds for calibration.
        
    Returns:
        XGBClassifier or CalibratedClassifierCV object.
    """
    default_params = {
        "n_estimators": 20,
        "learning_rate": 0.1,
        "max_depth": 6,
        "min_child_weight": 1,
        "gamma": 1e-2,
        "colsample_bytree": 0.7,
        "subsample": 0.75,
        "reg_alpha": 1e-2,
        "tree_method": "hist",
        "n_jobs": -1,
        "random_state": 42
    }
    
    if params:
        default_params.update(params)  # Override defaults with provided values
    
    clf = XGBClassifier(**default_params)
    
    if calibrate:
        clf = CalibratedClassifierCV(clf, cv=cv, method="isotonic")
    
    return clf

# %%
def plot_ROC_curve(fpr, tpr, roc_auc, title):
    plt.figure(figsize=[5, 5])
    plt.title(title)
    plt.plot(fpr, tpr, color='b',
                 label=r'XGB (AUC = %0.3f)' % (roc_auc),
                 lw=2, alpha=.8)
    plt.plot([0, 1], [0, 1], linestyle='--', lw=1, color='grey', alpha=.5)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate = 1 - Specificity')
    plt.ylabel('True Positive Rate = Sensitivity')
    plt.legend(loc="lower right")
    plt.show()

# %%
def results(pred_probas):
    OMI_score = np.round(pred_probas[:, 1]*100, decimals=2)
    y_pred = np.where(OMI_score<5, 'Low risk', 'Intermediate risk')
    y_pred = np.where(OMI_score>=20, 'High risk', y_pred)
    
    results = {
        'Low risk': [np.count_nonzero(y_pred == 'Low risk')],
        'Intermediate risk': [np.count_nonzero(y_pred == 'Intermediate risk')],
        'High risk': [np.count_nonzero(y_pred == 'High risk')]
    }
    return(pd.DataFrame(data=results, index=['Count (N)']))

# %%
def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=1000, alpha=0.05):
    """
    Compute 95% confidence interval using bootstrapping for any metric.
    
    Parameters:
    - y_true: Ground truth labels (0 or 1).
    - y_pred: Predicted values (either probabilities or binary predictions).
    - metric_fn: Metric function (roc_auc_score, recall_score, f1_score).
    - n_bootstrap: Number of bootstrap resamples.
    - alpha: Significance level (default 0.05 for 95% CI).

    Returns:
    - Lower and upper bound of the confidence interval.
    """
    scores = []
    
    for _ in range(n_bootstrap):
        # Resample dataset with replacement
        indices = resample(range(len(y_true)), replace=True, n_samples=len(y_true))
        y_true_bootstrap = np.array(y_true)[indices]
        y_pred_bootstrap = np.array(y_pred)[indices]

        # Special case for AUROC: Use roc_curve and auc()
        if metric_fn == "auroc":
            fpr, tpr, _ = roc_curve(y_true_bootstrap, y_pred_bootstrap)
            score = auc(fpr, tpr)
        else:
            score = metric_fn(y_true_bootstrap, y_pred_bootstrap)

        scores.append(score)
    
    # Compute confidence interval
    lower_bound = np.percentile(scores, 100 * (alpha / 2))
    upper_bound = np.percentile(scores, 100 * (1 - alpha / 2))
    
    return lower_bound, upper_bound

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from itertools import product
import numpy as np
import json

def xgb_hyperparameter_tuning_cv(X, y, param_grid=None, n_folds=10, random_state=42):
    """
    Perform hyperparameter tuning for XGBClassifier using K-fold cross-validation.
    
    Args:
        X, y: Training data (numpy arrays or pandas DataFrames)
        param_grid (dict): Dictionary of hyperparameter lists to search
        n_folds (int): Number of folds for cross-validation
        random_state (int): Random seed for reproducibility
        
    Returns:
        best_params: The best hyperparameters found
        best_score: Best mean AUROC score
        cv_results: Detailed results for all parameter combinations
    """
    print(f"Hyperparameter Tuning with {n_folds}-fold Cross-Validation")
    
    # Convert to numpy arrays if they are not already
    if hasattr(X, 'values'):
        X = X.values
    if hasattr(y, 'values'):
        y = y.values
    
    # Minimal grid if not provided
    if param_grid is None:
        param_grid = {
            "n_estimators": [50, 100],
            "max_depth": [3, 4],
            "learning_rate": [0.05, 0.1],
            "subsample": [0.8],
            "colsample_bytree": [0.8]
        }
    
    # Set default for optional params if not in grid
    if "reg_alpha" not in param_grid:
        param_grid["reg_alpha"] = [0]
    if "reg_lambda" not in param_grid:
        param_grid["reg_lambda"] = [1]
        
    best_mean_auroc = 0
    best_params = {}
    cv_results = []
    
    # Create KFold object
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)
    
    # Total number of parameter combinations
    param_combinations = [len(v) for v in param_grid.values()]
    total_combinations = np.prod(param_combinations)
    print(f"Searching through {total_combinations} parameter combinations...")
    
    # Iterate over all combinations of hyperparameters
    for i, params in enumerate(product(*param_grid.values())):
        param_names = list(param_grid.keys())
        current_params = dict(zip(param_names, params))
        
        print(f"\nParameter combination {i+1}/{total_combinations}:")
        print(f"Params: {current_params}")
        
        # Store fold results
        fold_scores = []
        
        # Perform k-fold cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
            X_train_fold, X_val_fold = X[train_idx], X[val_idx]
            y_train_fold, y_val_fold = y[train_idx], y[val_idx]
            
            # Train model
            current_xgb = XGBClassifier(
                **current_params,
                tree_method="hist",
                n_jobs=-1,
                random_state=random_state
            )
            
            current_xgb.fit(X_train_fold, y_train_fold)
            
            # Predict probabilities and calculate AUROC
            val_probas = current_xgb.predict_proba(X_val_fold)
            auroc = roc_auc_score(y_val_fold, val_probas[:, 1])
            fold_scores.append(auroc)
            
            print(f"  Fold {fold+1}/{n_folds} - AUROC: {auroc:.4f}")
        
        # Calculate mean and std of AUROC across folds
        mean_auroc = np.mean(fold_scores)
        std_auroc = np.std(fold_scores)
        print(f"  Mean AUROC: {mean_auroc:.4f} ± {std_auroc:.4f}")
        
        # Store results for this parameter combination
        cv_results.append({
            "params": current_params,
            "mean_auroc": mean_auroc,
            "std_auroc": std_auroc,
            "fold_scores": fold_scores
        })
        
        # Update best parameters if better mean AUROC is found
        if mean_auroc > best_mean_auroc:
            best_mean_auroc = mean_auroc
            best_params = current_params
    
    # Print and save best results
    print("\n" + "="*50)
    print("Best Parameters:")
    for param, value in best_params.items():
        print(f"  {param}: {value}")
    print(f"Best Mean AUROC: {best_mean_auroc:.4f}")
    
    # Sort results by mean AUROC
    cv_results.sort(key=lambda x: x["mean_auroc"], reverse=True)
    
    # Save best parameters to a file
    with open("best_xgb_params_cv.json", "w") as f:
        json.dump(best_params, f, indent=4)
    
    # Train final model on all data with best parameters
    final_model = XGBClassifier(
        **best_params,
        tree_method="hist",
        n_jobs=-1,
        random_state=random_state
    )
    final_model.fit(X, y)
    
    return final_model, best_params, cv_results

# %%
# Define your parameter grid
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.8, 0.9],
    "colsample_bytree": [0.7, 0.8, 0.9],
    "reg_alpha": [0, 0.1, 1],
    "reg_lambda": [0, 1, 10]
}

# Run cross-validation hyperparameter tuning
best_model, best_params, cv_results = xgb_hyperparameter_tuning_cv(X_train, y_train, param_grid=param_grid)

# Print top 5 parameter combinations
print("\nTop 5 Parameter Combinations:")
for i, result in enumerate(cv_results[:5]):
    print(f"{i+1}. Mean AUROC: {result['mean_auroc']:.4f} ± {result['std_auroc']:.4f}")
    print(f"   Parameters: {result['params']}")
# Out:
# Hyperparameter Tuning with 10-fold Cross-Validation
# Searching through 2187 parameter combinations...
#
# Parameter combination 1/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7571
#   Fold 2/10 - AUROC: 0.8094
#   Fold 3/10 - AUROC: 0.8583
#   Fold 4/10 - AUROC: 0.9393
#   Fold 5/10 - AUROC: 0.9442
#   Fold 6/10 - AUROC: 0.8946
#   Fold 7/10 - AUROC: 0.8768
#   Fold 8/10 - AUROC: 0.8971
#   Fold 9/10 - AUROC: 0.7910
#   Fold 10/10 - AUROC: 0.8719
#   Mean AUROC: 0.8640 ± 0.0584
#
# Parameter combination 2/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7454
#   Fold 2/10 - AUROC: 0.8148
#   Fold 3/10 - AUROC: 0.8712
#   Fold 4/10 - AUROC: 0.9447
#   Fold 5/10 - AUROC: 0.9338
#   Fold 6/10 - AUROC: 0.8958
#   Fold 7/10 - AUROC: 0.8696
#   Fold 8/10 - AUROC: 0.8883
#   Fold 9/10 - AUROC: 0.7941
#   Fold 10/10 - AUROC: 0.8695
#   Mean AUROC: 0.8627 ± 0.0587
#
# Parameter combination 3/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7478
#   Fold 2/10 - AUROC: 0.8311
#   Fold 3/10 - AUROC: 0.8491
#   Fold 4/10 - AUROC: 0.9319
#   Fold 5/10 - AUROC: 0.9303
#   Fold 6/10 - AUROC: 0.8666
#   Fold 7/10 - AUROC: 0.8442
#   Fold 8/10 - AUROC: 0.8704
#   Fold 9/10 - AUROC: 0.8030
#   Fold 10/10 - AUROC: 0.8659
#   Mean AUROC: 0.8540 ± 0.0519
#
# Parameter combination 4/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7526
#   Fold 2/10 - AUROC: 0.8072
#   Fold 3/10 - AUROC: 0.8612
#   Fold 4/10 - AUROC: 0.9407
#   Fold 5/10 - AUROC: 0.9435
#   Fold 6/10 - AUROC: 0.8939
#   Fold 7/10 - AUROC: 0.8719
#   Fold 8/10 - AUROC: 0.8962
#   Fold 9/10 - AUROC: 0.7902
#   Fold 10/10 - AUROC: 0.8704
#   Mean AUROC: 0.8628 ± 0.0594
#
# Parameter combination 5/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7452
#   Fold 2/10 - AUROC: 0.8194
#   Fold 3/10 - AUROC: 0.8728
#   Fold 4/10 - AUROC: 0.9442
#   Fold 5/10 - AUROC: 0.9358
#   Fold 6/10 - AUROC: 0.8946
#   Fold 7/10 - AUROC: 0.8660
#   Fold 8/10 - AUROC: 0.8942
#   Fold 9/10 - AUROC: 0.7781
#   Fold 10/10 - AUROC: 0.8704
#   Mean AUROC: 0.8621 ± 0.0608
#
# Parameter combination 6/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7482
#   Fold 2/10 - AUROC: 0.8297
#   Fold 3/10 - AUROC: 0.8497
#   Fold 4/10 - AUROC: 0.9319
#   Fold 5/10 - AUROC: 0.9295
#   Fold 6/10 - AUROC: 0.8654
#   Fold 7/10 - AUROC: 0.8440
#   Fold 8/10 - AUROC: 0.8739
#   Fold 9/10 - AUROC: 0.8022
#   Fold 10/10 - AUROC: 0.8649
#   Mean AUROC: 0.8539 ± 0.0520
#
# Parameter combination 7/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7520
#   Fold 2/10 - AUROC: 0.8183
#   Fold 3/10 - AUROC: 0.8566
#   Fold 4/10 - AUROC: 0.9516
#   Fold 5/10 - AUROC: 0.9480
#   Fold 6/10 - AUROC: 0.8874
#   Fold 7/10 - AUROC: 0.8647
#   Fold 8/10 - AUROC: 0.9024
#   Fold 9/10 - AUROC: 0.7884
#   Fold 10/10 - AUROC: 0.8733
#   Mean AUROC: 0.8643 ± 0.0610
#
# Parameter combination 8/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7472
#   Fold 2/10 - AUROC: 0.8211
#   Fold 3/10 - AUROC: 0.8572
#   Fold 4/10 - AUROC: 0.9441
#   Fold 5/10 - AUROC: 0.9353
#   Fold 6/10 - AUROC: 0.8886
#   Fold 7/10 - AUROC: 0.8632
#   Fold 8/10 - AUROC: 0.8769
#   Fold 9/10 - AUROC: 0.7894
#   Fold 10/10 - AUROC: 0.8717
#   Mean AUROC: 0.8595 ± 0.0576
#
# Parameter combination 9/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7416
#   Fold 2/10 - AUROC: 0.8309
#   Fold 3/10 - AUROC: 0.8497
#   Fold 4/10 - AUROC: 0.9307
#   Fold 5/10 - AUROC: 0.9281
#   Fold 6/10 - AUROC: 0.8686
#   Fold 7/10 - AUROC: 0.8466
#   Fold 8/10 - AUROC: 0.8695
#   Fold 9/10 - AUROC: 0.8066
#   Fold 10/10 - AUROC: 0.8636
#   Mean AUROC: 0.8536 ± 0.0523
#
# Parameter combination 10/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7537
#   Fold 2/10 - AUROC: 0.8279
#   Fold 3/10 - AUROC: 0.8729
#   Fold 4/10 - AUROC: 0.9453
#   Fold 5/10 - AUROC: 0.9480
#   Fold 6/10 - AUROC: 0.8999
#   Fold 7/10 - AUROC: 0.8692
#   Fold 8/10 - AUROC: 0.8942
#   Fold 9/10 - AUROC: 0.7949
#   Fold 10/10 - AUROC: 0.8801
#   Mean AUROC: 0.8686 ± 0.0585
#
# Parameter combination 11/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7458
#   Fold 2/10 - AUROC: 0.8293
#   Fold 3/10 - AUROC: 0.8714
#   Fold 4/10 - AUROC: 0.9447
#   Fold 5/10 - AUROC: 0.9370
#   Fold 6/10 - AUROC: 0.8913
#   Fold 7/10 - AUROC: 0.8576
#   Fold 8/10 - AUROC: 0.8939
#   Fold 9/10 - AUROC: 0.7968
#   Fold 10/10 - AUROC: 0.8791
#   Mean AUROC: 0.8647 ± 0.0579
#
# Parameter combination 12/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7486
#   Fold 2/10 - AUROC: 0.8368
#   Fold 3/10 - AUROC: 0.8591
#   Fold 4/10 - AUROC: 0.9286
#   Fold 5/10 - AUROC: 0.9315
#   Fold 6/10 - AUROC: 0.8673
#   Fold 7/10 - AUROC: 0.8476
#   Fold 8/10 - AUROC: 0.8723
#   Fold 9/10 - AUROC: 0.7977
#   Fold 10/10 - AUROC: 0.8570
#   Mean AUROC: 0.8546 ± 0.0517
#
# Parameter combination 13/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7516
#   Fold 2/10 - AUROC: 0.8305
#   Fold 3/10 - AUROC: 0.8745
#   Fold 4/10 - AUROC: 0.9453
#   Fold 5/10 - AUROC: 0.9505
#   Fold 6/10 - AUROC: 0.8998
#   Fold 7/10 - AUROC: 0.8702
#   Fold 8/10 - AUROC: 0.8954
#   Fold 9/10 - AUROC: 0.7952
#   Fold 10/10 - AUROC: 0.8798
#   Mean AUROC: 0.8693 ± 0.0591
#
# Parameter combination 14/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7440
#   Fold 2/10 - AUROC: 0.8329
#   Fold 3/10 - AUROC: 0.8714
#   Fold 4/10 - AUROC: 0.9458
#   Fold 5/10 - AUROC: 0.9432
#   Fold 6/10 - AUROC: 0.8911
#   Fold 7/10 - AUROC: 0.8633
#   Fold 8/10 - AUROC: 0.8924
#   Fold 9/10 - AUROC: 0.7968
#   Fold 10/10 - AUROC: 0.8776
#   Mean AUROC: 0.8659 ± 0.0588
#
# Parameter combination 15/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7484
#   Fold 2/10 - AUROC: 0.8382
#   Fold 3/10 - AUROC: 0.8589
#   Fold 4/10 - AUROC: 0.9288
#   Fold 5/10 - AUROC: 0.9318
#   Fold 6/10 - AUROC: 0.8464
#   Fold 7/10 - AUROC: 0.8472
#   Fold 8/10 - AUROC: 0.8711
#   Fold 9/10 - AUROC: 0.7961
#   Fold 10/10 - AUROC: 0.8583
#   Mean AUROC: 0.8525 ± 0.0518
#
# Parameter combination 16/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7483
#   Fold 2/10 - AUROC: 0.8299
#   Fold 3/10 - AUROC: 0.8691
#   Fold 4/10 - AUROC: 0.9501
#   Fold 5/10 - AUROC: 0.9512
#   Fold 6/10 - AUROC: 0.8946
#   Fold 7/10 - AUROC: 0.8671
#   Fold 8/10 - AUROC: 0.8994
#   Fold 9/10 - AUROC: 0.7933
#   Fold 10/10 - AUROC: 0.8736
#   Mean AUROC: 0.8677 ± 0.0606
#
# Parameter combination 17/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7491
#   Fold 2/10 - AUROC: 0.8249
#   Fold 3/10 - AUROC: 0.8579
#   Fold 4/10 - AUROC: 0.9434
#   Fold 5/10 - AUROC: 0.9442
#   Fold 6/10 - AUROC: 0.8960
#   Fold 7/10 - AUROC: 0.8582
#   Fold 8/10 - AUROC: 0.8720
#   Fold 9/10 - AUROC: 0.7977
#   Fold 10/10 - AUROC: 0.8760
#   Mean AUROC: 0.8619 ± 0.0576
#
# Parameter combination 18/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7445
#   Fold 2/10 - AUROC: 0.8366
#   Fold 3/10 - AUROC: 0.8574
#   Fold 4/10 - AUROC: 0.9430
#   Fold 5/10 - AUROC: 0.9348
#   Fold 6/10 - AUROC: 0.8440
#   Fold 7/10 - AUROC: 0.8494
#   Fold 8/10 - AUROC: 0.8711
#   Fold 9/10 - AUROC: 0.8031
#   Fold 10/10 - AUROC: 0.8553
#   Mean AUROC: 0.8539 ± 0.0546
#
# Parameter combination 19/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7593
#   Fold 2/10 - AUROC: 0.8107
#   Fold 3/10 - AUROC: 0.8902
#   Fold 4/10 - AUROC: 0.9478
#   Fold 5/10 - AUROC: 0.9447
#   Fold 6/10 - AUROC: 0.8979
#   Fold 7/10 - AUROC: 0.8768
#   Fold 8/10 - AUROC: 0.9057
#   Fold 9/10 - AUROC: 0.7810
#   Fold 10/10 - AUROC: 0.8712
#   Mean AUROC: 0.8685 ± 0.0615
#
# Parameter combination 20/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7477
#   Fold 2/10 - AUROC: 0.8145
#   Fold 3/10 - AUROC: 0.8857
#   Fold 4/10 - AUROC: 0.9388
#   Fold 5/10 - AUROC: 0.9432
#   Fold 6/10 - AUROC: 0.8909
#   Fold 7/10 - AUROC: 0.8737
#   Fold 8/10 - AUROC: 0.8989
#   Fold 9/10 - AUROC: 0.7871
#   Fold 10/10 - AUROC: 0.8742
#   Mean AUROC: 0.8655 ± 0.0603
#
# Parameter combination 21/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7393
#   Fold 2/10 - AUROC: 0.8307
#   Fold 3/10 - AUROC: 0.8830
#   Fold 4/10 - AUROC: 0.9407
#   Fold 5/10 - AUROC: 0.9313
#   Fold 6/10 - AUROC: 0.8813
#   Fold 7/10 - AUROC: 0.8536
#   Fold 8/10 - AUROC: 0.8699
#   Fold 9/10 - AUROC: 0.7913
#   Fold 10/10 - AUROC: 0.8681
#   Mean AUROC: 0.8589 ± 0.0574
#
# Parameter combination 22/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7580
#   Fold 2/10 - AUROC: 0.8180
#   Fold 3/10 - AUROC: 0.8946
#   Fold 4/10 - AUROC: 0.9382
#   Fold 5/10 - AUROC: 0.9442
#   Fold 6/10 - AUROC: 0.8968
#   Fold 7/10 - AUROC: 0.8757
#   Fold 8/10 - AUROC: 0.9049
#   Fold 9/10 - AUROC: 0.7863
#   Fold 10/10 - AUROC: 0.8717
#   Mean AUROC: 0.8688 ± 0.0591
#
# Parameter combination 23/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7498
#   Fold 2/10 - AUROC: 0.8207
#   Fold 3/10 - AUROC: 0.8861
#   Fold 4/10 - AUROC: 0.9363
#   Fold 5/10 - AUROC: 0.9440
#   Fold 6/10 - AUROC: 0.8907
#   Fold 7/10 - AUROC: 0.8745
#   Fold 8/10 - AUROC: 0.9003
#   Fold 9/10 - AUROC: 0.7887
#   Fold 10/10 - AUROC: 0.8747
#   Mean AUROC: 0.8666 ± 0.0591
#
# Parameter combination 24/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7403
#   Fold 2/10 - AUROC: 0.8376
#   Fold 3/10 - AUROC: 0.8826
#   Fold 4/10 - AUROC: 0.9409
#   Fold 5/10 - AUROC: 0.9313
#   Fold 6/10 - AUROC: 0.8809
#   Fold 7/10 - AUROC: 0.8534
#   Fold 8/10 - AUROC: 0.8711
#   Fold 9/10 - AUROC: 0.7907
#   Fold 10/10 - AUROC: 0.8693
#   Mean AUROC: 0.8598 ± 0.0570
#
# Parameter combination 25/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7528
#   Fold 2/10 - AUROC: 0.8171
#   Fold 3/10 - AUROC: 0.8892
#   Fold 4/10 - AUROC: 0.9498
#   Fold 5/10 - AUROC: 0.9492
#   Fold 6/10 - AUROC: 0.8977
#   Fold 7/10 - AUROC: 0.8732
#   Fold 8/10 - AUROC: 0.9005
#   Fold 9/10 - AUROC: 0.7871
#   Fold 10/10 - AUROC: 0.8735
#   Mean AUROC: 0.8690 ± 0.0617
#
# Parameter combination 26/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7478
#   Fold 2/10 - AUROC: 0.8244
#   Fold 3/10 - AUROC: 0.8883
#   Fold 4/10 - AUROC: 0.9463
#   Fold 5/10 - AUROC: 0.9432
#   Fold 6/10 - AUROC: 0.8903
#   Fold 7/10 - AUROC: 0.8677
#   Fold 8/10 - AUROC: 0.8737
#   Fold 9/10 - AUROC: 0.7923
#   Fold 10/10 - AUROC: 0.8788
#   Mean AUROC: 0.8653 ± 0.0590
#
# Parameter combination 27/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7287
#   Fold 2/10 - AUROC: 0.8363
#   Fold 3/10 - AUROC: 0.8808
#   Fold 4/10 - AUROC: 0.9430
#   Fold 5/10 - AUROC: 0.9318
#   Fold 6/10 - AUROC: 0.8499
#   Fold 7/10 - AUROC: 0.8549
#   Fold 8/10 - AUROC: 0.8688
#   Fold 9/10 - AUROC: 0.7880
#   Fold 10/10 - AUROC: 0.8670
#   Mean AUROC: 0.8549 ± 0.0595
#
# Parameter combination 28/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7430
#   Fold 2/10 - AUROC: 0.8296
#   Fold 3/10 - AUROC: 0.8689
#   Fold 4/10 - AUROC: 0.9378
#   Fold 5/10 - AUROC: 0.9457
#   Fold 6/10 - AUROC: 0.8647
#   Fold 7/10 - AUROC: 0.8669
#   Fold 8/10 - AUROC: 0.9053
#   Fold 9/10 - AUROC: 0.7825
#   Fold 10/10 - AUROC: 0.8700
#   Mean AUROC: 0.8614 ± 0.0603
#
# Parameter combination 29/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7533
#   Fold 2/10 - AUROC: 0.8273
#   Fold 3/10 - AUROC: 0.8723
#   Fold 4/10 - AUROC: 0.9409
#   Fold 5/10 - AUROC: 0.9432
#   Fold 6/10 - AUROC: 0.8635
#   Fold 7/10 - AUROC: 0.8621
#   Fold 8/10 - AUROC: 0.8927
#   Fold 9/10 - AUROC: 0.8097
#   Fold 10/10 - AUROC: 0.8651
#   Mean AUROC: 0.8630 ± 0.0544
#
# Parameter combination 30/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7421
#   Fold 2/10 - AUROC: 0.8450
#   Fold 3/10 - AUROC: 0.8858
#   Fold 4/10 - AUROC: 0.9233
#   Fold 5/10 - AUROC: 0.9293
#   Fold 6/10 - AUROC: 0.8409
#   Fold 7/10 - AUROC: 0.8498
#   Fold 8/10 - AUROC: 0.8670
#   Fold 9/10 - AUROC: 0.7991
#   Fold 10/10 - AUROC: 0.8686
#   Mean AUROC: 0.8551 ± 0.0526
#
# Parameter combination 31/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7383
#   Fold 2/10 - AUROC: 0.8228
#   Fold 3/10 - AUROC: 0.8709
#   Fold 4/10 - AUROC: 0.9384
#   Fold 5/10 - AUROC: 0.9442
#   Fold 6/10 - AUROC: 0.8618
#   Fold 7/10 - AUROC: 0.8635
#   Fold 8/10 - AUROC: 0.9041
#   Fold 9/10 - AUROC: 0.7823
#   Fold 10/10 - AUROC: 0.8690
#   Mean AUROC: 0.8595 ± 0.0613
#
# Parameter combination 32/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7525
#   Fold 2/10 - AUROC: 0.8293
#   Fold 3/10 - AUROC: 0.8695
#   Fold 4/10 - AUROC: 0.9406
#   Fold 5/10 - AUROC: 0.9440
#   Fold 6/10 - AUROC: 0.8653
#   Fold 7/10 - AUROC: 0.8623
#   Fold 8/10 - AUROC: 0.8924
#   Fold 9/10 - AUROC: 0.8085
#   Fold 10/10 - AUROC: 0.8662
#   Mean AUROC: 0.8631 ± 0.0546
#
# Parameter combination 33/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7429
#   Fold 2/10 - AUROC: 0.8441
#   Fold 3/10 - AUROC: 0.8858
#   Fold 4/10 - AUROC: 0.9233
#   Fold 5/10 - AUROC: 0.9291
#   Fold 6/10 - AUROC: 0.8399
#   Fold 7/10 - AUROC: 0.8500
#   Fold 8/10 - AUROC: 0.8667
#   Fold 9/10 - AUROC: 0.7985
#   Fold 10/10 - AUROC: 0.8684
#   Mean AUROC: 0.8549 ± 0.0525
#
# Parameter combination 34/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7500
#   Fold 2/10 - AUROC: 0.8296
#   Fold 3/10 - AUROC: 0.8505
#   Fold 4/10 - AUROC: 0.9336
#   Fold 5/10 - AUROC: 0.9440
#   Fold 6/10 - AUROC: 0.8497
#   Fold 7/10 - AUROC: 0.8623
#   Fold 8/10 - AUROC: 0.8933
#   Fold 9/10 - AUROC: 0.8120
#   Fold 10/10 - AUROC: 0.8713
#   Mean AUROC: 0.8596 ± 0.0541
#
# Parameter combination 35/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7488
#   Fold 2/10 - AUROC: 0.8301
#   Fold 3/10 - AUROC: 0.8540
#   Fold 4/10 - AUROC: 0.9359
#   Fold 5/10 - AUROC: 0.9398
#   Fold 6/10 - AUROC: 0.8476
#   Fold 7/10 - AUROC: 0.8407
#   Fold 8/10 - AUROC: 0.8712
#   Fold 9/10 - AUROC: 0.7969
#   Fold 10/10 - AUROC: 0.8707
#   Mean AUROC: 0.8536 ± 0.0545
#
# Parameter combination 36/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7436
#   Fold 2/10 - AUROC: 0.8436
#   Fold 3/10 - AUROC: 0.8837
#   Fold 4/10 - AUROC: 0.9274
#   Fold 5/10 - AUROC: 0.9303
#   Fold 6/10 - AUROC: 0.8429
#   Fold 7/10 - AUROC: 0.8481
#   Fold 8/10 - AUROC: 0.8667
#   Fold 9/10 - AUROC: 0.7983
#   Fold 10/10 - AUROC: 0.8692
#   Mean AUROC: 0.8554 ± 0.0529
#
# Parameter combination 37/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7413
#   Fold 2/10 - AUROC: 0.8338
#   Fold 3/10 - AUROC: 0.8603
#   Fold 4/10 - AUROC: 0.9352
#   Fold 5/10 - AUROC: 0.9408
#   Fold 6/10 - AUROC: 0.8697
#   Fold 7/10 - AUROC: 0.8580
#   Fold 8/10 - AUROC: 0.9151
#   Fold 9/10 - AUROC: 0.7523
#   Fold 10/10 - AUROC: 0.8743
#   Mean AUROC: 0.8581 ± 0.0647
#
# Parameter combination 38/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7515
#   Fold 2/10 - AUROC: 0.8411
#   Fold 3/10 - AUROC: 0.8613
#   Fold 4/10 - AUROC: 0.9386
#   Fold 5/10 - AUROC: 0.9380
#   Fold 6/10 - AUROC: 0.8707
#   Fold 7/10 - AUROC: 0.8489
#   Fold 8/10 - AUROC: 0.8999
#   Fold 9/10 - AUROC: 0.7503
#   Fold 10/10 - AUROC: 0.8733
#   Mean AUROC: 0.8574 ± 0.0620
#
# Parameter combination 39/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7339
#   Fold 2/10 - AUROC: 0.8445
#   Fold 3/10 - AUROC: 0.8591
#   Fold 4/10 - AUROC: 0.9244
#   Fold 5/10 - AUROC: 0.9313
#   Fold 6/10 - AUROC: 0.8421
#   Fold 7/10 - AUROC: 0.8460
#   Fold 8/10 - AUROC: 0.8688
#   Fold 9/10 - AUROC: 0.7704
#   Fold 10/10 - AUROC: 0.8738
#   Mean AUROC: 0.8494 ± 0.0575
#
# Parameter combination 40/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7405
#   Fold 2/10 - AUROC: 0.8362
#   Fold 3/10 - AUROC: 0.8615
#   Fold 4/10 - AUROC: 0.9357
#   Fold 5/10 - AUROC: 0.9435
#   Fold 6/10 - AUROC: 0.8701
#   Fold 7/10 - AUROC: 0.8571
#   Fold 8/10 - AUROC: 0.9130
#   Fold 9/10 - AUROC: 0.7481
#   Fold 10/10 - AUROC: 0.8736
#   Mean AUROC: 0.8579 ± 0.0657
#
# Parameter combination 41/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7512
#   Fold 2/10 - AUROC: 0.8423
#   Fold 3/10 - AUROC: 0.8645
#   Fold 4/10 - AUROC: 0.9397
#   Fold 5/10 - AUROC: 0.9395
#   Fold 6/10 - AUROC: 0.8762
#   Fold 7/10 - AUROC: 0.8476
#   Fold 8/10 - AUROC: 0.8996
#   Fold 9/10 - AUROC: 0.7473
#   Fold 10/10 - AUROC: 0.8724
#   Mean AUROC: 0.8580 ± 0.0630
#
# Parameter combination 42/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7339
#   Fold 2/10 - AUROC: 0.8445
#   Fold 3/10 - AUROC: 0.8593
#   Fold 4/10 - AUROC: 0.9250
#   Fold 5/10 - AUROC: 0.9320
#   Fold 6/10 - AUROC: 0.8425
#   Fold 7/10 - AUROC: 0.8459
#   Fold 8/10 - AUROC: 0.8685
#   Fold 9/10 - AUROC: 0.7656
#   Fold 10/10 - AUROC: 0.8747
#   Mean AUROC: 0.8492 ± 0.0584
#
# Parameter combination 43/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7454
#   Fold 2/10 - AUROC: 0.8416
#   Fold 3/10 - AUROC: 0.8612
#   Fold 4/10 - AUROC: 0.9371
#   Fold 5/10 - AUROC: 0.9437
#   Fold 6/10 - AUROC: 0.8460
#   Fold 7/10 - AUROC: 0.8371
#   Fold 8/10 - AUROC: 0.9075
#   Fold 9/10 - AUROC: 0.7444
#   Fold 10/10 - AUROC: 0.8753
#   Mean AUROC: 0.8539 ± 0.0653
#
# Parameter combination 44/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7434
#   Fold 2/10 - AUROC: 0.8412
#   Fold 3/10 - AUROC: 0.8612
#   Fold 4/10 - AUROC: 0.9355
#   Fold 5/10 - AUROC: 0.9378
#   Fold 6/10 - AUROC: 0.8450
#   Fold 7/10 - AUROC: 0.8379
#   Fold 8/10 - AUROC: 0.9013
#   Fold 9/10 - AUROC: 0.7484
#   Fold 10/10 - AUROC: 0.8757
#   Mean AUROC: 0.8527 ± 0.0635
#
# Parameter combination 45/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7303
#   Fold 2/10 - AUROC: 0.8483
#   Fold 3/10 - AUROC: 0.8757
#   Fold 4/10 - AUROC: 0.9198
#   Fold 5/10 - AUROC: 0.9323
#   Fold 6/10 - AUROC: 0.8407
#   Fold 7/10 - AUROC: 0.8469
#   Fold 8/10 - AUROC: 0.8699
#   Fold 9/10 - AUROC: 0.7661
#   Fold 10/10 - AUROC: 0.8740
#   Mean AUROC: 0.8504 ± 0.0589
#
# Parameter combination 46/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7333
#   Fold 2/10 - AUROC: 0.8310
#   Fold 3/10 - AUROC: 0.8884
#   Fold 4/10 - AUROC: 0.9436
#   Fold 5/10 - AUROC: 0.9502
#   Fold 6/10 - AUROC: 0.8718
#   Fold 7/10 - AUROC: 0.8591
#   Fold 8/10 - AUROC: 0.9144
#   Fold 9/10 - AUROC: 0.7567
#   Fold 10/10 - AUROC: 0.8716
#   Mean AUROC: 0.8620 ± 0.0683
#
# Parameter combination 47/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7406
#   Fold 2/10 - AUROC: 0.8310
#   Fold 3/10 - AUROC: 0.8816
#   Fold 4/10 - AUROC: 0.9389
#   Fold 5/10 - AUROC: 0.9457
#   Fold 6/10 - AUROC: 0.8669
#   Fold 7/10 - AUROC: 0.8451
#   Fold 8/10 - AUROC: 0.9082
#   Fold 9/10 - AUROC: 0.7632
#   Fold 10/10 - AUROC: 0.8740
#   Mean AUROC: 0.8595 ± 0.0643
#
# Parameter combination 48/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7213
#   Fold 2/10 - AUROC: 0.8510
#   Fold 3/10 - AUROC: 0.8583
#   Fold 4/10 - AUROC: 0.9258
#   Fold 5/10 - AUROC: 0.9355
#   Fold 6/10 - AUROC: 0.8392
#   Fold 7/10 - AUROC: 0.8407
#   Fold 8/10 - AUROC: 0.8688
#   Fold 9/10 - AUROC: 0.7867
#   Fold 10/10 - AUROC: 0.8731
#   Mean AUROC: 0.8500 ± 0.0590
#
# Parameter combination 49/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7327
#   Fold 2/10 - AUROC: 0.8303
#   Fold 3/10 - AUROC: 0.8890
#   Fold 4/10 - AUROC: 0.9437
#   Fold 5/10 - AUROC: 0.9485
#   Fold 6/10 - AUROC: 0.8684
#   Fold 7/10 - AUROC: 0.8570
#   Fold 8/10 - AUROC: 0.9129
#   Fold 9/10 - AUROC: 0.7578
#   Fold 10/10 - AUROC: 0.8721
#   Mean AUROC: 0.8612 ± 0.0680
#
# Parameter combination 50/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7502
#   Fold 2/10 - AUROC: 0.8308
#   Fold 3/10 - AUROC: 0.8837
#   Fold 4/10 - AUROC: 0.9397
#   Fold 5/10 - AUROC: 0.9445
#   Fold 6/10 - AUROC: 0.8625
#   Fold 7/10 - AUROC: 0.8450
#   Fold 8/10 - AUROC: 0.9068
#   Fold 9/10 - AUROC: 0.7578
#   Fold 10/10 - AUROC: 0.8730
#   Mean AUROC: 0.8594 ± 0.0632
#
# Parameter combination 51/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7214
#   Fold 2/10 - AUROC: 0.8510
#   Fold 3/10 - AUROC: 0.8585
#   Fold 4/10 - AUROC: 0.9259
#   Fold 5/10 - AUROC: 0.9360
#   Fold 6/10 - AUROC: 0.8375
#   Fold 7/10 - AUROC: 0.8427
#   Fold 8/10 - AUROC: 0.8679
#   Fold 9/10 - AUROC: 0.7851
#   Fold 10/10 - AUROC: 0.8757
#   Mean AUROC: 0.8502 ± 0.0593
#
# Parameter combination 52/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7461
#   Fold 2/10 - AUROC: 0.8286
#   Fold 3/10 - AUROC: 0.8769
#   Fold 4/10 - AUROC: 0.9365
#   Fold 5/10 - AUROC: 0.9492
#   Fold 6/10 - AUROC: 0.8447
#   Fold 7/10 - AUROC: 0.8375
#   Fold 8/10 - AUROC: 0.9057
#   Fold 9/10 - AUROC: 0.7571
#   Fold 10/10 - AUROC: 0.8745
#   Mean AUROC: 0.8557 ± 0.0644
#
# Parameter combination 53/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7441
#   Fold 2/10 - AUROC: 0.8343
#   Fold 3/10 - AUROC: 0.8789
#   Fold 4/10 - AUROC: 0.9359
#   Fold 5/10 - AUROC: 0.9435
#   Fold 6/10 - AUROC: 0.8411
#   Fold 7/10 - AUROC: 0.8375
#   Fold 8/10 - AUROC: 0.9028
#   Fold 9/10 - AUROC: 0.7526
#   Fold 10/10 - AUROC: 0.8766
#   Mean AUROC: 0.8547 ± 0.0644
#
# Parameter combination 54/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7209
#   Fold 2/10 - AUROC: 0.8466
#   Fold 3/10 - AUROC: 0.8709
#   Fold 4/10 - AUROC: 0.9278
#   Fold 5/10 - AUROC: 0.9335
#   Fold 6/10 - AUROC: 0.8365
#   Fold 7/10 - AUROC: 0.8459
#   Fold 8/10 - AUROC: 0.8724
#   Fold 9/10 - AUROC: 0.7809
#   Fold 10/10 - AUROC: 0.8733
#   Mean AUROC: 0.8509 ± 0.0601
#
# Parameter combination 55/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7363
#   Fold 2/10 - AUROC: 0.8244
#   Fold 3/10 - AUROC: 0.8873
#   Fold 4/10 - AUROC: 0.9453
#   Fold 5/10 - AUROC: 0.9400
#   Fold 6/10 - AUROC: 0.8639
#   Fold 7/10 - AUROC: 0.8625
#   Fold 8/10 - AUROC: 0.9117
#   Fold 9/10 - AUROC: 0.7949
#   Fold 10/10 - AUROC: 0.8632
#   Mean AUROC: 0.8629 ± 0.0615
#
# Parameter combination 56/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7415
#   Fold 2/10 - AUROC: 0.8383
#   Fold 3/10 - AUROC: 0.8928
#   Fold 4/10 - AUROC: 0.9436
#   Fold 5/10 - AUROC: 0.9390
#   Fold 6/10 - AUROC: 0.8647
#   Fold 7/10 - AUROC: 0.8468
#   Fold 8/10 - AUROC: 0.9019
#   Fold 9/10 - AUROC: 0.7983
#   Fold 10/10 - AUROC: 0.8593
#   Mean AUROC: 0.8626 ± 0.0588
#
# Parameter combination 57/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7344
#   Fold 2/10 - AUROC: 0.8264
#   Fold 3/10 - AUROC: 0.8704
#   Fold 4/10 - AUROC: 0.9306
#   Fold 5/10 - AUROC: 0.9254
#   Fold 6/10 - AUROC: 0.8645
#   Fold 7/10 - AUROC: 0.8478
#   Fold 8/10 - AUROC: 0.8777
#   Fold 9/10 - AUROC: 0.7957
#   Fold 10/10 - AUROC: 0.8729
#   Mean AUROC: 0.8546 ± 0.0555
#
# Parameter combination 58/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7353
#   Fold 2/10 - AUROC: 0.8323
#   Fold 3/10 - AUROC: 0.8885
#   Fold 4/10 - AUROC: 0.9431
#   Fold 5/10 - AUROC: 0.9408
#   Fold 6/10 - AUROC: 0.8628
#   Fold 7/10 - AUROC: 0.8619
#   Fold 8/10 - AUROC: 0.9117
#   Fold 9/10 - AUROC: 0.7938
#   Fold 10/10 - AUROC: 0.8647
#   Mean AUROC: 0.8635 ± 0.0613
#
# Parameter combination 59/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7382
#   Fold 2/10 - AUROC: 0.8385
#   Fold 3/10 - AUROC: 0.8907
#   Fold 4/10 - AUROC: 0.9431
#   Fold 5/10 - AUROC: 0.9395
#   Fold 6/10 - AUROC: 0.8641
#   Fold 7/10 - AUROC: 0.8460
#   Fold 8/10 - AUROC: 0.9041
#   Fold 9/10 - AUROC: 0.8001
#   Fold 10/10 - AUROC: 0.8579
#   Mean AUROC: 0.8622 ± 0.0593
#
# Parameter combination 60/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7343
#   Fold 2/10 - AUROC: 0.8367
#   Fold 3/10 - AUROC: 0.8706
#   Fold 4/10 - AUROC: 0.9311
#   Fold 5/10 - AUROC: 0.9252
#   Fold 6/10 - AUROC: 0.8655
#   Fold 7/10 - AUROC: 0.8490
#   Fold 8/10 - AUROC: 0.8809
#   Fold 9/10 - AUROC: 0.7948
#   Fold 10/10 - AUROC: 0.8726
#   Mean AUROC: 0.8561 ± 0.0553
#
# Parameter combination 61/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7421
#   Fold 2/10 - AUROC: 0.8366
#   Fold 3/10 - AUROC: 0.8739
#   Fold 4/10 - AUROC: 0.9437
#   Fold 5/10 - AUROC: 0.9385
#   Fold 6/10 - AUROC: 0.8618
#   Fold 7/10 - AUROC: 0.8405
#   Fold 8/10 - AUROC: 0.9046
#   Fold 9/10 - AUROC: 0.7992
#   Fold 10/10 - AUROC: 0.8666
#   Mean AUROC: 0.8607 ± 0.0582
#
# Parameter combination 62/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7403
#   Fold 2/10 - AUROC: 0.8181
#   Fold 3/10 - AUROC: 0.8603
#   Fold 4/10 - AUROC: 0.9417
#   Fold 5/10 - AUROC: 0.9358
#   Fold 6/10 - AUROC: 0.8567
#   Fold 7/10 - AUROC: 0.8397
#   Fold 8/10 - AUROC: 0.8949
#   Fold 9/10 - AUROC: 0.7995
#   Fold 10/10 - AUROC: 0.8602
#   Mean AUROC: 0.8547 ± 0.0579
#
# Parameter combination 63/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7365
#   Fold 2/10 - AUROC: 0.8359
#   Fold 3/10 - AUROC: 0.8653
#   Fold 4/10 - AUROC: 0.9309
#   Fold 5/10 - AUROC: 0.9266
#   Fold 6/10 - AUROC: 0.8607
#   Fold 7/10 - AUROC: 0.8523
#   Fold 8/10 - AUROC: 0.8771
#   Fold 9/10 - AUROC: 0.7976
#   Fold 10/10 - AUROC: 0.8743
#   Mean AUROC: 0.8557 ± 0.0544
#
# Parameter combination 64/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7430
#   Fold 2/10 - AUROC: 0.8310
#   Fold 3/10 - AUROC: 0.8809
#   Fold 4/10 - AUROC: 0.9484
#   Fold 5/10 - AUROC: 0.9525
#   Fold 6/10 - AUROC: 0.8549
#   Fold 7/10 - AUROC: 0.8702
#   Fold 8/10 - AUROC: 0.9161
#   Fold 9/10 - AUROC: 0.7800
#   Fold 10/10 - AUROC: 0.8559
#   Mean AUROC: 0.8633 ± 0.0640
#
# Parameter combination 65/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7440
#   Fold 2/10 - AUROC: 0.8389
#   Fold 3/10 - AUROC: 0.8909
#   Fold 4/10 - AUROC: 0.9482
#   Fold 5/10 - AUROC: 0.9415
#   Fold 6/10 - AUROC: 0.8642
#   Fold 7/10 - AUROC: 0.8629
#   Fold 8/10 - AUROC: 0.9130
#   Fold 9/10 - AUROC: 0.7704
#   Fold 10/10 - AUROC: 0.8675
#   Mean AUROC: 0.8642 ± 0.0633
#
# Parameter combination 66/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7469
#   Fold 2/10 - AUROC: 0.8425
#   Fold 3/10 - AUROC: 0.8680
#   Fold 4/10 - AUROC: 0.9484
#   Fold 5/10 - AUROC: 0.9276
#   Fold 6/10 - AUROC: 0.8684
#   Fold 7/10 - AUROC: 0.8567
#   Fold 8/10 - AUROC: 0.8888
#   Fold 9/10 - AUROC: 0.8090
#   Fold 10/10 - AUROC: 0.8729
#   Mean AUROC: 0.8629 ± 0.0540
#
# Parameter combination 67/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7424
#   Fold 2/10 - AUROC: 0.8305
#   Fold 3/10 - AUROC: 0.8803
#   Fold 4/10 - AUROC: 0.9477
#   Fold 5/10 - AUROC: 0.9532
#   Fold 6/10 - AUROC: 0.8575
#   Fold 7/10 - AUROC: 0.8691
#   Fold 8/10 - AUROC: 0.9202
#   Fold 9/10 - AUROC: 0.7821
#   Fold 10/10 - AUROC: 0.8554
#   Mean AUROC: 0.8638 ± 0.0641
#
# Parameter combination 68/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7481
#   Fold 2/10 - AUROC: 0.8422
#   Fold 3/10 - AUROC: 0.8889
#   Fold 4/10 - AUROC: 0.9481
#   Fold 5/10 - AUROC: 0.9420
#   Fold 6/10 - AUROC: 0.8646
#   Fold 7/10 - AUROC: 0.8631
#   Fold 8/10 - AUROC: 0.9157
#   Fold 9/10 - AUROC: 0.7720
#   Fold 10/10 - AUROC: 0.8671
#   Mean AUROC: 0.8652 ± 0.0623
#
# Parameter combination 69/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7464
#   Fold 2/10 - AUROC: 0.8425
#   Fold 3/10 - AUROC: 0.8680
#   Fold 4/10 - AUROC: 0.9479
#   Fold 5/10 - AUROC: 0.9300
#   Fold 6/10 - AUROC: 0.8673
#   Fold 7/10 - AUROC: 0.8569
#   Fold 8/10 - AUROC: 0.8879
#   Fold 9/10 - AUROC: 0.8103
#   Fold 10/10 - AUROC: 0.8733
#   Mean AUROC: 0.8631 ± 0.0541
#
# Parameter combination 70/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7522
#   Fold 2/10 - AUROC: 0.8424
#   Fold 3/10 - AUROC: 0.8736
#   Fold 4/10 - AUROC: 0.9511
#   Fold 5/10 - AUROC: 0.9457
#   Fold 6/10 - AUROC: 0.8598
#   Fold 7/10 - AUROC: 0.8624
#   Fold 8/10 - AUROC: 0.9125
#   Fold 9/10 - AUROC: 0.7726
#   Fold 10/10 - AUROC: 0.8642
#   Mean AUROC: 0.8636 ± 0.0617
#
# Parameter combination 71/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7480
#   Fold 2/10 - AUROC: 0.8438
#   Fold 3/10 - AUROC: 0.8730
#   Fold 4/10 - AUROC: 0.9510
#   Fold 5/10 - AUROC: 0.9435
#   Fold 6/10 - AUROC: 0.8631
#   Fold 7/10 - AUROC: 0.8654
#   Fold 8/10 - AUROC: 0.9101
#   Fold 9/10 - AUROC: 0.7749
#   Fold 10/10 - AUROC: 0.8612
#   Mean AUROC: 0.8634 ± 0.0616
#
# Parameter combination 72/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7428
#   Fold 2/10 - AUROC: 0.8321
#   Fold 3/10 - AUROC: 0.8629
#   Fold 4/10 - AUROC: 0.9320
#   Fold 5/10 - AUROC: 0.9294
#   Fold 6/10 - AUROC: 0.8619
#   Fold 7/10 - AUROC: 0.8593
#   Fold 8/10 - AUROC: 0.8829
#   Fold 9/10 - AUROC: 0.8074
#   Fold 10/10 - AUROC: 0.8736
#   Mean AUROC: 0.8584 ± 0.0529
#
# Parameter combination 73/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7579
#   Fold 2/10 - AUROC: 0.8243
#   Fold 3/10 - AUROC: 0.8792
#   Fold 4/10 - AUROC: 0.9380
#   Fold 5/10 - AUROC: 0.9525
#   Fold 6/10 - AUROC: 0.8559
#   Fold 7/10 - AUROC: 0.8691
#   Fold 8/10 - AUROC: 0.9127
#   Fold 9/10 - AUROC: 0.7852
#   Fold 10/10 - AUROC: 0.8603
#   Mean AUROC: 0.8635 ± 0.0592
#
# Parameter combination 74/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7568
#   Fold 2/10 - AUROC: 0.8184
#   Fold 3/10 - AUROC: 0.8703
#   Fold 4/10 - AUROC: 0.9445
#   Fold 5/10 - AUROC: 0.9472
#   Fold 6/10 - AUROC: 0.8644
#   Fold 7/10 - AUROC: 0.8647
#   Fold 8/10 - AUROC: 0.9120
#   Fold 9/10 - AUROC: 0.7711
#   Fold 10/10 - AUROC: 0.8671
#   Mean AUROC: 0.8617 ± 0.0616
#
# Parameter combination 75/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7428
#   Fold 2/10 - AUROC: 0.8277
#   Fold 3/10 - AUROC: 0.8578
#   Fold 4/10 - AUROC: 0.9396
#   Fold 5/10 - AUROC: 0.9298
#   Fold 6/10 - AUROC: 0.8420
#   Fold 7/10 - AUROC: 0.8579
#   Fold 8/10 - AUROC: 0.8809
#   Fold 9/10 - AUROC: 0.7735
#   Fold 10/10 - AUROC: 0.8724
#   Mean AUROC: 0.8524 ± 0.0581
#
# Parameter combination 76/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7514
#   Fold 2/10 - AUROC: 0.8240
#   Fold 3/10 - AUROC: 0.8784
#   Fold 4/10 - AUROC: 0.9378
#   Fold 5/10 - AUROC: 0.9495
#   Fold 6/10 - AUROC: 0.8567
#   Fold 7/10 - AUROC: 0.8696
#   Fold 8/10 - AUROC: 0.9125
#   Fold 9/10 - AUROC: 0.7855
#   Fold 10/10 - AUROC: 0.8587
#   Mean AUROC: 0.8624 ± 0.0599
#
# Parameter combination 77/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7559
#   Fold 2/10 - AUROC: 0.8292
#   Fold 3/10 - AUROC: 0.8705
#   Fold 4/10 - AUROC: 0.9438
#   Fold 5/10 - AUROC: 0.9472
#   Fold 6/10 - AUROC: 0.8670
#   Fold 7/10 - AUROC: 0.8652
#   Fold 8/10 - AUROC: 0.9144
#   Fold 9/10 - AUROC: 0.7714
#   Fold 10/10 - AUROC: 0.8675
#   Mean AUROC: 0.8632 ± 0.0611
#
# Parameter combination 78/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7425
#   Fold 2/10 - AUROC: 0.8277
#   Fold 3/10 - AUROC: 0.8578
#   Fold 4/10 - AUROC: 0.9407
#   Fold 5/10 - AUROC: 0.9298
#   Fold 6/10 - AUROC: 0.8420
#   Fold 7/10 - AUROC: 0.8588
#   Fold 8/10 - AUROC: 0.8829
#   Fold 9/10 - AUROC: 0.7722
#   Fold 10/10 - AUROC: 0.8745
#   Mean AUROC: 0.8529 ± 0.0587
#
# Parameter combination 79/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7600
#   Fold 2/10 - AUROC: 0.8317
#   Fold 3/10 - AUROC: 0.8429
#   Fold 4/10 - AUROC: 0.9458
#   Fold 5/10 - AUROC: 0.9495
#   Fold 6/10 - AUROC: 0.8590
#   Fold 7/10 - AUROC: 0.8685
#   Fold 8/10 - AUROC: 0.9089
#   Fold 9/10 - AUROC: 0.7710
#   Fold 10/10 - AUROC: 0.8700
#   Mean AUROC: 0.8607 ± 0.0608
#
# Parameter combination 80/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7522
#   Fold 2/10 - AUROC: 0.8381
#   Fold 3/10 - AUROC: 0.8658
#   Fold 4/10 - AUROC: 0.9451
#   Fold 5/10 - AUROC: 0.9442
#   Fold 6/10 - AUROC: 0.8593
#   Fold 7/10 - AUROC: 0.8681
#   Fold 8/10 - AUROC: 0.9054
#   Fold 9/10 - AUROC: 0.7741
#   Fold 10/10 - AUROC: 0.8719
#   Mean AUROC: 0.8624 ± 0.0601
#
# Parameter combination 81/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7416
#   Fold 2/10 - AUROC: 0.8396
#   Fold 3/10 - AUROC: 0.8548
#   Fold 4/10 - AUROC: 0.9417
#   Fold 5/10 - AUROC: 0.9335
#   Fold 6/10 - AUROC: 0.8398
#   Fold 7/10 - AUROC: 0.8582
#   Fold 8/10 - AUROC: 0.8813
#   Fold 9/10 - AUROC: 0.7660
#   Fold 10/10 - AUROC: 0.8700
#   Mean AUROC: 0.8526 ± 0.0598
#
# Parameter combination 82/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7819
#   Fold 2/10 - AUROC: 0.8031
#   Fold 3/10 - AUROC: 0.8889
#   Fold 4/10 - AUROC: 0.9456
#   Fold 5/10 - AUROC: 0.9465
#   Fold 6/10 - AUROC: 0.9118
#   Fold 7/10 - AUROC: 0.9037
#   Fold 8/10 - AUROC: 0.9334
#   Fold 9/10 - AUROC: 0.7848
#   Fold 10/10 - AUROC: 0.9230
#   Mean AUROC: 0.8823 ± 0.0629
#
# Parameter combination 83/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7745
#   Fold 2/10 - AUROC: 0.8170
#   Fold 3/10 - AUROC: 0.8993
#   Fold 4/10 - AUROC: 0.9466
#   Fold 5/10 - AUROC: 0.9412
#   Fold 6/10 - AUROC: 0.9191
#   Fold 7/10 - AUROC: 0.9024
#   Fold 8/10 - AUROC: 0.9228
#   Fold 9/10 - AUROC: 0.7844
#   Fold 10/10 - AUROC: 0.9240
#   Mean AUROC: 0.8831 ± 0.0621
#
# Parameter combination 84/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7781
#   Fold 2/10 - AUROC: 0.8246
#   Fold 3/10 - AUROC: 0.8940
#   Fold 4/10 - AUROC: 0.9567
#   Fold 5/10 - AUROC: 0.9403
#   Fold 6/10 - AUROC: 0.9195
#   Fold 7/10 - AUROC: 0.9026
#   Fold 8/10 - AUROC: 0.8959
#   Fold 9/10 - AUROC: 0.7993
#   Fold 10/10 - AUROC: 0.8980
#   Mean AUROC: 0.8809 ± 0.0568
#
# Parameter combination 85/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7843
#   Fold 2/10 - AUROC: 0.8037
#   Fold 3/10 - AUROC: 0.8911
#   Fold 4/10 - AUROC: 0.9420
#   Fold 5/10 - AUROC: 0.9452
#   Fold 6/10 - AUROC: 0.9060
#   Fold 7/10 - AUROC: 0.9115
#   Fold 8/10 - AUROC: 0.9293
#   Fold 9/10 - AUROC: 0.8073
#   Fold 10/10 - AUROC: 0.9189
#   Mean AUROC: 0.8839 ± 0.0583
#
# Parameter combination 86/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7791
#   Fold 2/10 - AUROC: 0.8101
#   Fold 3/10 - AUROC: 0.8946
#   Fold 4/10 - AUROC: 0.9491
#   Fold 5/10 - AUROC: 0.9465
#   Fold 6/10 - AUROC: 0.9234
#   Fold 7/10 - AUROC: 0.9095
#   Fold 8/10 - AUROC: 0.9231
#   Fold 9/10 - AUROC: 0.7903
#   Fold 10/10 - AUROC: 0.9228
#   Mean AUROC: 0.8849 ± 0.0622
#
# Parameter combination 87/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7778
#   Fold 2/10 - AUROC: 0.8241
#   Fold 3/10 - AUROC: 0.8893
#   Fold 4/10 - AUROC: 0.9556
#   Fold 5/10 - AUROC: 0.9403
#   Fold 6/10 - AUROC: 0.9177
#   Fold 7/10 - AUROC: 0.9022
#   Fold 8/10 - AUROC: 0.8898
#   Fold 9/10 - AUROC: 0.7991
#   Fold 10/10 - AUROC: 0.8960
#   Mean AUROC: 0.8792 ± 0.0564
#
# Parameter combination 88/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7828
#   Fold 2/10 - AUROC: 0.8042
#   Fold 3/10 - AUROC: 0.8795
#   Fold 4/10 - AUROC: 0.9468
#   Fold 5/10 - AUROC: 0.9447
#   Fold 6/10 - AUROC: 0.9103
#   Fold 7/10 - AUROC: 0.9000
#   Fold 8/10 - AUROC: 0.9196
#   Fold 9/10 - AUROC: 0.7927
#   Fold 10/10 - AUROC: 0.9214
#   Mean AUROC: 0.8802 ± 0.0600
#
# Parameter combination 89/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7815
#   Fold 2/10 - AUROC: 0.8150
#   Fold 3/10 - AUROC: 0.8891
#   Fold 4/10 - AUROC: 0.9446
#   Fold 5/10 - AUROC: 0.9408
#   Fold 6/10 - AUROC: 0.9126
#   Fold 7/10 - AUROC: 0.9084
#   Fold 8/10 - AUROC: 0.9199
#   Fold 9/10 - AUROC: 0.8177
#   Fold 10/10 - AUROC: 0.9174
#   Mean AUROC: 0.8847 ± 0.0551
#
# Parameter combination 90/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7770
#   Fold 2/10 - AUROC: 0.8244
#   Fold 3/10 - AUROC: 0.8905
#   Fold 4/10 - AUROC: 0.9568
#   Fold 5/10 - AUROC: 0.9393
#   Fold 6/10 - AUROC: 0.9140
#   Fold 7/10 - AUROC: 0.9015
#   Fold 8/10 - AUROC: 0.8939
#   Fold 9/10 - AUROC: 0.7974
#   Fold 10/10 - AUROC: 0.8934
#   Mean AUROC: 0.8788 ± 0.0566
#
# Parameter combination 91/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7815
#   Fold 2/10 - AUROC: 0.8193
#   Fold 3/10 - AUROC: 0.8942
#   Fold 4/10 - AUROC: 0.9468
#   Fold 5/10 - AUROC: 0.9375
#   Fold 6/10 - AUROC: 0.9210
#   Fold 7/10 - AUROC: 0.9075
#   Fold 8/10 - AUROC: 0.9053
#   Fold 9/10 - AUROC: 0.7977
#   Fold 10/10 - AUROC: 0.9094
#   Mean AUROC: 0.8820 ± 0.0566
#
# Parameter combination 92/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7889
#   Fold 2/10 - AUROC: 0.8214
#   Fold 3/10 - AUROC: 0.8958
#   Fold 4/10 - AUROC: 0.9507
#   Fold 5/10 - AUROC: 0.9457
#   Fold 6/10 - AUROC: 0.9242
#   Fold 7/10 - AUROC: 0.9079
#   Fold 8/10 - AUROC: 0.9138
#   Fold 9/10 - AUROC: 0.7941
#   Fold 10/10 - AUROC: 0.9109
#   Mean AUROC: 0.8854 ± 0.0576
#
# Parameter combination 93/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7815
#   Fold 2/10 - AUROC: 0.8300
#   Fold 3/10 - AUROC: 0.8854
#   Fold 4/10 - AUROC: 0.9490
#   Fold 5/10 - AUROC: 0.9405
#   Fold 6/10 - AUROC: 0.9220
#   Fold 7/10 - AUROC: 0.9002
#   Fold 8/10 - AUROC: 0.8983
#   Fold 9/10 - AUROC: 0.8038
#   Fold 10/10 - AUROC: 0.9030
#   Mean AUROC: 0.8814 ± 0.0543
#
# Parameter combination 94/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7810
#   Fold 2/10 - AUROC: 0.8102
#   Fold 3/10 - AUROC: 0.8997
#   Fold 4/10 - AUROC: 0.9498
#   Fold 5/10 - AUROC: 0.9368
#   Fold 6/10 - AUROC: 0.9252
#   Fold 7/10 - AUROC: 0.9130
#   Fold 8/10 - AUROC: 0.9208
#   Fold 9/10 - AUROC: 0.7953
#   Fold 10/10 - AUROC: 0.9098
#   Mean AUROC: 0.8842 ± 0.0599
#
# Parameter combination 95/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7889
#   Fold 2/10 - AUROC: 0.8201
#   Fold 3/10 - AUROC: 0.8940
#   Fold 4/10 - AUROC: 0.9510
#   Fold 5/10 - AUROC: 0.9422
#   Fold 6/10 - AUROC: 0.9187
#   Fold 7/10 - AUROC: 0.9084
#   Fold 8/10 - AUROC: 0.9132
#   Fold 9/10 - AUROC: 0.7962
#   Fold 10/10 - AUROC: 0.9121
#   Mean AUROC: 0.8845 ± 0.0568
#
# Parameter combination 96/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7880
#   Fold 2/10 - AUROC: 0.8297
#   Fold 3/10 - AUROC: 0.8871
#   Fold 4/10 - AUROC: 0.9493
#   Fold 5/10 - AUROC: 0.9408
#   Fold 6/10 - AUROC: 0.9205
#   Fold 7/10 - AUROC: 0.8999
#   Fold 8/10 - AUROC: 0.8994
#   Fold 9/10 - AUROC: 0.8032
#   Fold 10/10 - AUROC: 0.8997
#   Mean AUROC: 0.8817 ± 0.0531
#
# Parameter combination 97/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7831
#   Fold 2/10 - AUROC: 0.8145
#   Fold 3/10 - AUROC: 0.8944
#   Fold 4/10 - AUROC: 0.9484
#   Fold 5/10 - AUROC: 0.9432
#   Fold 6/10 - AUROC: 0.9281
#   Fold 7/10 - AUROC: 0.9097
#   Fold 8/10 - AUROC: 0.9158
#   Fold 9/10 - AUROC: 0.7925
#   Fold 10/10 - AUROC: 0.9123
#   Mean AUROC: 0.8842 ± 0.0596
#
# Parameter combination 98/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7856
#   Fold 2/10 - AUROC: 0.8158
#   Fold 3/10 - AUROC: 0.8956
#   Fold 4/10 - AUROC: 0.9479
#   Fold 5/10 - AUROC: 0.9410
#   Fold 6/10 - AUROC: 0.9212
#   Fold 7/10 - AUROC: 0.9125
#   Fold 8/10 - AUROC: 0.9237
#   Fold 9/10 - AUROC: 0.7871
#   Fold 10/10 - AUROC: 0.9081
#   Mean AUROC: 0.8838 ± 0.0596
#
# Parameter combination 99/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 1, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7759
#   Fold 2/10 - AUROC: 0.8308
#   Fold 3/10 - AUROC: 0.8848
#   Fold 4/10 - AUROC: 0.9453
#   Fold 5/10 - AUROC: 0.9425
#   Fold 6/10 - AUROC: 0.9177
#   Fold 7/10 - AUROC: 0.8978
#   Fold 8/10 - AUROC: 0.8936
#   Fold 9/10 - AUROC: 0.7957
#   Fold 10/10 - AUROC: 0.8914
#   Mean AUROC: 0.8776 ± 0.0553
#
# Parameter combination 100/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7703
#   Fold 2/10 - AUROC: 0.8110
#   Fold 3/10 - AUROC: 0.8946
#   Fold 4/10 - AUROC: 0.9459
#   Fold 5/10 - AUROC: 0.9520
#   Fold 6/10 - AUROC: 0.9208
#   Fold 7/10 - AUROC: 0.9024
#   Fold 8/10 - AUROC: 0.9176
#   Fold 9/10 - AUROC: 0.7974
#   Fold 10/10 - AUROC: 0.8917
#   Mean AUROC: 0.8804 ± 0.0609
#
# Parameter combination 101/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7760
#   Fold 2/10 - AUROC: 0.8213
#   Fold 3/10 - AUROC: 0.8962
#   Fold 4/10 - AUROC: 0.9481
#   Fold 5/10 - AUROC: 0.9420
#   Fold 6/10 - AUROC: 0.9244
#   Fold 7/10 - AUROC: 0.9062
#   Fold 8/10 - AUROC: 0.9030
#   Fold 9/10 - AUROC: 0.7805
#   Fold 10/10 - AUROC: 0.9013
#   Mean AUROC: 0.8799 ± 0.0605
#
# Parameter combination 102/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 10}
#   Fold 1/10 - AUROC: 0.7892
#   Fold 2/10 - AUROC: 0.8157
#   Fold 3/10 - AUROC: 0.8828
#   Fold 4/10 - AUROC: 0.9431
#   Fold 5/10 - AUROC: 0.9417
#   Fold 6/10 - AUROC: 0.9118
#   Fold 7/10 - AUROC: 0.8995
#   Fold 8/10 - AUROC: 0.9056
#   Fold 9/10 - AUROC: 0.7880
#   Fold 10/10 - AUROC: 0.8982
#   Mean AUROC: 0.8776 ± 0.0556
#
# Parameter combination 103/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 0}
#   Fold 1/10 - AUROC: 0.7743
#   Fold 2/10 - AUROC: 0.8169
#   Fold 3/10 - AUROC: 0.9058
#   Fold 4/10 - AUROC: 0.9434
#   Fold 5/10 - AUROC: 0.9517
#   Fold 6/10 - AUROC: 0.9224
#   Fold 7/10 - AUROC: 0.9218
#   Fold 8/10 - AUROC: 0.9082
#   Fold 9/10 - AUROC: 0.7786
#   Fold 10/10 - AUROC: 0.8977
#   Mean AUROC: 0.8821 ± 0.0631
#
# Parameter combination 104/2187:
# Params: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 1}
#   Fold 1/10 - AUROC: 0.7763
#   Fold 2/10 - AUROC: 0.8183
#   Fold 3/10 - AUROC: 0.9016
#   Fold 4/10 - AUROC: 0.9507

# %%
# 1. Train the best model on the entire training set
best_xgb = XGBClassifier(
    n_estimators=100,
    max_depth=4,
    learning_rate=best_params["learning_rate"],
    subsample=best_params["subsample"],
    colsample_bytree=best_params["colsample_bytree"],
    reg_alpha=best_params["reg_alpha"],
    reg_lambda=best_params["reg_lambda"],
    tree_method="hist",
    n_jobs=-1,
    random_state=42
)

# Fit the model on the entire training set
best_xgb.fit(X_train, y_train)

# 2. Predict on training data
pred_probas_train = best_xgb.predict_proba(X_train)

# 3. Compute ROC curve and area under the curve
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_train, pred_probas_train[:,1])
roc_auc = auc(fpr, tpr)

# 4. Plot ROC curve
plot_ROC_curve(fpr, tpr, roc_auc, 'Training curve: Derivation cohort (ROC curves)')

# 5. Compute AUROC CI using bootstrap
auroc_ci_lower_train, auroc_ci_upper_train = bootstrap_metric_ci(y_train, pred_probas_train[:,1], "auroc")
print(f"Training AUROC: {roc_auc:.3f} (95% CI: {auroc_ci_lower_train:.3f}, {auroc_ci_upper_train:.3f})")

# 6. Save the model for future use
import pickle
with open('best_xgb_model.pkl', 'wb') as f:
    pickle.dump(best_xgb, f)
# Out:
# Training AUROC: 0.998 (95% CI: 0.996, 0.999)

# %%
# Evaluate XGBoost model on validation set
print("\nValidation Set Evaluation:")
pred_probas_val = best_model.predict_proba(X_val)

# Compute ROC curve and area under the curve for validation set
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, pred_probas_val[:,1])
roc_auc_val = auc(fpr_val, tpr_val)

# Plot the ROC curve
plot_ROC_curve(fpr_val, tpr_val, roc_auc_val, 'Validation curve: XGBoost (ROC curves)')

# Compute AUROC CI using bootstrap
auroc_ci_lower_val, auroc_ci_upper_val = bootstrap_metric_ci(y_val, pred_probas_val[:,1], "auroc")

# Print results
print(f"Validation AUROC: {roc_auc_val:.3f} (95% CI: {auroc_ci_lower_val:.3f}, {auroc_ci_upper_val:.3f})")
# Out:
# Validation Set Evaluation:
# Validation AUROC: 0.896 (95% CI: 0.872, 0.918)
