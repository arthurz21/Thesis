# %%
from sklearn.linear_model import SGDClassifier  # Replaces KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
import os
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import precision_score, recall_score, f1_score
from copy import deepcopy
from math import sqrt
from sklearn.utils import resample
from sklearn.metrics import make_scorer, recall_score
from sklearn.pipeline import make_pipeline

# %%
derivation_cohort = pd.read_csv("Derivation_dataset.csv")
external_validation_cohort = pd.read_csv("External_validation_dataset.csv")

y = derivation_cohort['Outcome_Occlusion_MI']
X = derivation_cohort.drop('Outcome_Occlusion_MI', axis=1)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify = y, random_state = 99)

for el in X_train.columns:
    X_train[el].fillna(X_train[el].mode()[0], inplace=True)
    X_val[el].fillna(X_train[el].mode()[0], inplace=True)

y_train = np.ravel(np.array(y_train.values))
y_val = np.ravel(np.array(y_val.values))

columns = X_train.columns

X_train = np.array(X_train.values)
X_val = np.array(X_val.values)

scaler = preprocessing.StandardScaler().fit(X_train) # Compute mean and std of training set
X_train = scaler.transform(X_train, copy=True)
X_val = scaler.transform(X_val, copy=True)
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_89864\1077325655.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_89864\1077325655.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_val[el].fillna(X_train[el].mode()[0], inplace=True)

# %%
def plot_ROC_curve(fpr, tpr, roc_auc, title):
    plt.figure(figsize=[5, 5])
    plt.title(title)
    plt.plot(fpr, tpr, color='b',
                 label=r'SGD_log_reg (AUC = %0.3f)' % (roc_auc),
                 lw=2, alpha=.8)
    plt.plot([0, 1], [0, 1], linestyle='--', lw=1, color='grey', alpha=.5)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate = 1 - Specificity')
    plt.ylabel('True Positive Rate = Sensitivity')
    plt.legend(loc="lower right")
    plt.show()

# %%
def results(pred_probas):
    OMI_score = np.round(pred_probas[:, 1]*100, decimals=2)
    y_pred = np.where(OMI_score<5, 'Low risk', 'Intermediate risk')
    y_pred = np.where(OMI_score>=20, 'High risk', y_pred)
    
    results = {
        'Low risk': [np.count_nonzero(y_pred == 'Low risk')],
        'Intermediate risk': [np.count_nonzero(y_pred == 'Intermediate risk')],
        'High risk': [np.count_nonzero(y_pred == 'High risk')]
    }
    return(pd.DataFrame(data=results, index=['Count (N)']))

# %%
def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=1000, alpha=0.05):
    """
    Compute 95% confidence interval using bootstrapping for any metric.
    
    Parameters:
    - y_true: Ground truth labels (0 or 1).
    - y_pred: Predicted values (either probabilities or binary predictions).
    - metric_fn: Metric function (roc_auc_score, recall_score, f1_score).
    - n_bootstrap: Number of bootstrap resamples.
    - alpha: Significance level (default 0.05 for 95% CI).

    Returns:
    - Lower and upper bound of the confidence interval.
    """
    scores = []
    
    for _ in range(n_bootstrap):
        # Resample dataset with replacement
        indices = resample(range(len(y_true)), replace=True, n_samples=len(y_true))
        y_true_bootstrap = np.array(y_true)[indices]
        y_pred_bootstrap = np.array(y_pred)[indices]

        # Special case for AUROC: Use roc_curve and auc()
        if metric_fn == "auroc":
            fpr, tpr, _ = roc_curve(y_true_bootstrap, y_pred_bootstrap)
            score = auc(fpr, tpr)
        else:
            score = metric_fn(y_true_bootstrap, y_pred_bootstrap)

        scores.append(score)
    
    # Compute confidence interval
    lower_bound = np.percentile(scores, 100 * (alpha / 2))
    upper_bound = np.percentile(scores, 100 * (1 - alpha / 2))
    
    return lower_bound, upper_bound

# %%
print("Hyperparameter Tuning on Validation Set")
best_score = 0
best_params = {}
best_model = None
print("Searching for optimal hyperparameters...")
for alpha in [0.0001, 0.001, 0.01, 0.1]:  # Regularization strength
    for penalty in ['l2', 'l1', 'elasticnet']:  # Regularization type
        for learning_rate in ['optimal', 'invscaling', 'constant', 'adaptive']:  # Learning rate schedule
            for eta0 in [0.01, 0.1, 1]:  # Initial learning rate, must be > 0
                
                # Ensure eta0 is used only when necessary
                params = {
                    'loss': 'log_loss', 'alpha': alpha, 'penalty': penalty,
                    'max_iter': 1000, 'tol': 1e-3, 'learning_rate': learning_rate
                }
                
                # eta0 is required for 'constant', 'invscaling', and 'adaptive' learning rates
                if learning_rate in ['constant', 'invscaling', 'adaptive']:
                    params['eta0'] = eta0
                
                # Create SGD Logistic Regression model with current parameters
                current_sgd = SGDClassifier(**params, random_state=42)
                
                try:
                    # Train on training set
                    current_sgd.fit(X_train, y_train)
                    
                    # Evaluate on validation set using AUROC
                    val_probas = current_sgd.predict_proba(X_val)[:, 1]  # Get positive class probabilities
                    auroc_val = roc_auc_score(y_val, val_probas)
                    
                    eta0_text = eta0 if learning_rate in ['constant', 'invscaling', 'adaptive'] else 'N/A'
                    print(f"Parameters: alpha={alpha}, penalty={penalty}, learning_rate={learning_rate}, eta0={eta0_text}, AUROC={auroc_val:.4f}")
                    
                    # Track best model based on AUROC
                    if auroc_val > best_score:
                        best_score = auroc_val
                        best_params = {
                            'alpha': alpha,
                            'penalty': penalty,
                            'learning_rate': learning_rate,
                            'eta0': eta0_text
                        }
                        best_model = current_sgd
                except Exception as e:
                    print(f"Error with parameters: alpha={alpha}, penalty={penalty}, learning_rate={learning_rate}, eta0={eta0 if learning_rate in ['constant', 'invscaling', 'adaptive'] else 'N/A'}")
                    print(f"Error message: {str(e)}")
                    continue

print(f"\nBest Parameters: {best_params}")
print(f"Best Validation AUROC score: {best_score:.4f}")
# Use the best model found
clf = best_model
# Out:
# Hyperparameter Tuning on Validation Set
# Searching for optimal hyperparameters...
# Parameters: alpha=0.0001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.7732
# Parameters: alpha=0.0001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.7732
# Parameters: alpha=0.0001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.7732
# Parameters: alpha=0.0001, penalty=l2, learning_rate=invscaling, eta0=0.01, AUROC=0.8348
# Parameters: alpha=0.0001, penalty=l2, learning_rate=invscaling, eta0=0.1, AUROC=0.8789
# Parameters: alpha=0.0001, penalty=l2, learning_rate=invscaling, eta0=1, AUROC=0.8644
# Parameters: alpha=0.0001, penalty=l2, learning_rate=constant, eta0=0.01, AUROC=0.8833
# Parameters: alpha=0.0001, penalty=l2, learning_rate=constant, eta0=0.1, AUROC=0.8059
# Parameters: alpha=0.0001, penalty=l2, learning_rate=constant, eta0=1, AUROC=0.7134
# Parameters: alpha=0.0001, penalty=l2, learning_rate=adaptive, eta0=0.01, AUROC=0.8768
# Parameters: alpha=0.0001, penalty=l2, learning_rate=adaptive, eta0=0.1, AUROC=0.8502
# Parameters: alpha=0.0001, penalty=l2, learning_rate=adaptive, eta0=1, AUROC=0.8467
# Parameters: alpha=0.0001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.8201
# Parameters: alpha=0.0001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.8201
# Parameters: alpha=0.0001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.8201
# Parameters: alpha=0.0001, penalty=l1, learning_rate=invscaling, eta0=0.01, AUROC=0.8340
# Parameters: alpha=0.0001, penalty=l1, learning_rate=invscaling, eta0=0.1, AUROC=0.8791
# Parameters: alpha=0.0001, penalty=l1, learning_rate=invscaling, eta0=1, AUROC=0.8666
# Parameters: alpha=0.0001, penalty=l1, learning_rate=constant, eta0=0.01, AUROC=0.8521
# Parameters: alpha=0.0001, penalty=l1, learning_rate=constant, eta0=0.1, AUROC=0.8063
# Parameters: alpha=0.0001, penalty=l1, learning_rate=constant, eta0=1, AUROC=0.7593
# Parameters: alpha=0.0001, penalty=l1, learning_rate=adaptive, eta0=0.01, AUROC=0.8730
# Parameters: alpha=0.0001, penalty=l1, learning_rate=adaptive, eta0=0.1, AUROC=0.8399
# Parameters: alpha=0.0001, penalty=l1, learning_rate=adaptive, eta0=1, AUROC=0.8458
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.7124
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.7124
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.7124
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=invscaling, eta0=0.01, AUROC=0.8348
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=invscaling, eta0=0.1, AUROC=0.8788
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=invscaling, eta0=1, AUROC=0.8652
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=constant, eta0=0.01, AUROC=0.8830
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=constant, eta0=0.1, AUROC=0.8005
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=constant, eta0=1, AUROC=0.7591
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=adaptive, eta0=0.01, AUROC=0.8769
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=adaptive, eta0=0.1, AUROC=0.8502
# Parameters: alpha=0.0001, penalty=elasticnet, learning_rate=adaptive, eta0=1, AUROC=0.8486
# Parameters: alpha=0.001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8646
# Parameters: alpha=0.001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8646
# Parameters: alpha=0.001, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8646
# Parameters: alpha=0.001, penalty=l2, learning_rate=invscaling, eta0=0.01, AUROC=0.8347
# Parameters: alpha=0.001, penalty=l2, learning_rate=invscaling, eta0=0.1, AUROC=0.8787
# Parameters: alpha=0.001, penalty=l2, learning_rate=invscaling, eta0=1, AUROC=0.8673
# Parameters: alpha=0.001, penalty=l2, learning_rate=constant, eta0=0.01, AUROC=0.8854
# Parameters: alpha=0.001, penalty=l2, learning_rate=constant, eta0=0.1, AUROC=0.7948
# Parameters: alpha=0.001, penalty=l2, learning_rate=constant, eta0=1, AUROC=0.7204
# Parameters: alpha=0.001, penalty=l2, learning_rate=adaptive, eta0=0.01, AUROC=0.8782
# Parameters: alpha=0.001, penalty=l2, learning_rate=adaptive, eta0=0.1, AUROC=0.8679
# Parameters: alpha=0.001, penalty=l2, learning_rate=adaptive, eta0=1, AUROC=0.8698
# Parameters: alpha=0.001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7646
# Parameters: alpha=0.001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7646
# Parameters: alpha=0.001, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7646
# Parameters: alpha=0.001, penalty=l1, learning_rate=invscaling, eta0=0.01, AUROC=0.8262
# Parameters: alpha=0.001, penalty=l1, learning_rate=invscaling, eta0=0.1, AUROC=0.8751
# Parameters: alpha=0.001, penalty=l1, learning_rate=invscaling, eta0=1, AUROC=0.8807
# Parameters: alpha=0.001, penalty=l1, learning_rate=constant, eta0=0.01, AUROC=0.8884
# Parameters: alpha=0.001, penalty=l1, learning_rate=constant, eta0=0.1, AUROC=0.7709
# Parameters: alpha=0.001, penalty=l1, learning_rate=constant, eta0=1, AUROC=0.8193
# Parameters: alpha=0.001, penalty=l1, learning_rate=adaptive, eta0=0.01, AUROC=0.8765
# Parameters: alpha=0.001, penalty=l1, learning_rate=adaptive, eta0=0.1, AUROC=0.8678
# Parameters: alpha=0.001, penalty=l1, learning_rate=adaptive, eta0=1, AUROC=0.8691
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8623
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8623
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8623
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=invscaling, eta0=0.01, AUROC=0.8333
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=invscaling, eta0=0.1, AUROC=0.8789
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=invscaling, eta0=1, AUROC=0.8707
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=constant, eta0=0.01, AUROC=0.8511
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=constant, eta0=0.1, AUROC=0.8077
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=constant, eta0=1, AUROC=0.7248
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=adaptive, eta0=0.01, AUROC=0.8766
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=adaptive, eta0=0.1, AUROC=0.8713
# Parameters: alpha=0.001, penalty=elasticnet, learning_rate=adaptive, eta0=1, AUROC=0.8713
# Parameters: alpha=0.01, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8736
# Parameters: alpha=0.01, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8736
# Parameters: alpha=0.01, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8736
# Parameters: alpha=0.01, penalty=l2, learning_rate=invscaling, eta0=0.01, AUROC=0.8332
# Parameters: alpha=0.01, penalty=l2, learning_rate=invscaling, eta0=0.1, AUROC=0.8755
# Parameters: alpha=0.01, penalty=l2, learning_rate=invscaling, eta0=1, AUROC=0.8851
# Parameters: alpha=0.01, penalty=l2, learning_rate=constant, eta0=0.01, AUROC=0.8857
# Parameters: alpha=0.01, penalty=l2, learning_rate=constant, eta0=0.1, AUROC=0.7197
# Parameters: alpha=0.01, penalty=l2, learning_rate=constant, eta0=1, AUROC=0.6266
# Parameters: alpha=0.01, penalty=l2, learning_rate=adaptive, eta0=0.01, AUROC=0.8821
# Parameters: alpha=0.01, penalty=l2, learning_rate=adaptive, eta0=0.1, AUROC=0.8812
# Parameters: alpha=0.01, penalty=l2, learning_rate=adaptive, eta0=1, AUROC=0.8816
# Parameters: alpha=0.01, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7905
# Parameters: alpha=0.01, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7905
# Parameters: alpha=0.01, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.7905
# Parameters: alpha=0.01, penalty=l1, learning_rate=invscaling, eta0=0.01, AUROC=0.7839
# Parameters: alpha=0.01, penalty=l1, learning_rate=invscaling, eta0=0.1, AUROC=0.8138
# Parameters: alpha=0.01, penalty=l1, learning_rate=invscaling, eta0=1, AUROC=0.8204
# Parameters: alpha=0.01, penalty=l1, learning_rate=constant, eta0=0.01, AUROC=0.8082
# Parameters: alpha=0.01, penalty=l1, learning_rate=constant, eta0=0.1, AUROC=0.7549
# Parameters: alpha=0.01, penalty=l1, learning_rate=constant, eta0=1, AUROC=0.5000
# Parameters: alpha=0.01, penalty=l1, learning_rate=adaptive, eta0=0.01, AUROC=0.8266
# Parameters: alpha=0.01, penalty=l1, learning_rate=adaptive, eta0=0.1, AUROC=0.8259
# Parameters: alpha=0.01, penalty=l1, learning_rate=adaptive, eta0=1, AUROC=0.8095
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8604
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8604
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.8604
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=invscaling, eta0=0.01, AUROC=0.8187
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=invscaling, eta0=0.1, AUROC=0.8650
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=invscaling, eta0=1, AUROC=0.8776
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=constant, eta0=0.01, AUROC=0.8828
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=constant, eta0=0.1, AUROC=0.7468
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=constant, eta0=1, AUROC=0.6688
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=adaptive, eta0=0.01, AUROC=0.8758
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=adaptive, eta0=0.1, AUROC=0.8728
# Parameters: alpha=0.01, penalty=elasticnet, learning_rate=adaptive, eta0=1, AUROC=0.8618
# Parameters: alpha=0.1, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8172
# Parameters: alpha=0.1, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8172
# Parameters: alpha=0.1, penalty=l2, learning_rate=optimal, eta0=N/A, AUROC=0.8172
# Parameters: alpha=0.1, penalty=l2, learning_rate=invscaling, eta0=0.01, AUROC=0.8165
# Parameters: alpha=0.1, penalty=l2, learning_rate=invscaling, eta0=0.1, AUROC=0.8270
# Parameters: alpha=0.1, penalty=l2, learning_rate=invscaling, eta0=1, AUROC=0.7598
# Parameters: alpha=0.1, penalty=l2, learning_rate=constant, eta0=0.01, AUROC=0.8453
# Parameters: alpha=0.1, penalty=l2, learning_rate=constant, eta0=0.1, AUROC=0.7088
# Parameters: alpha=0.1, penalty=l2, learning_rate=constant, eta0=1, AUROC=0.6584
# Parameters: alpha=0.1, penalty=l2, learning_rate=adaptive, eta0=0.01, AUROC=0.8249
# Parameters: alpha=0.1, penalty=l2, learning_rate=adaptive, eta0=0.1, AUROC=0.8252
# Parameters: alpha=0.1, penalty=l2, learning_rate=adaptive, eta0=1, AUROC=0.8268
# Parameters: alpha=0.1, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=optimal, eta0=N/A, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=invscaling, eta0=0.01, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=invscaling, eta0=0.1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=invscaling, eta0=1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=constant, eta0=0.01, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=constant, eta0=0.1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=constant, eta0=1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=adaptive, eta0=0.01, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=adaptive, eta0=0.1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=l1, learning_rate=adaptive, eta0=1, AUROC=0.5000
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.6655
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.6655
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=optimal, eta0=N/A, AUROC=0.6655
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=invscaling, eta0=0.01, AUROC=0.7532
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=invscaling, eta0=0.1, AUROC=0.7562
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=invscaling, eta0=1, AUROC=0.7831
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=constant, eta0=0.01, AUROC=0.7866
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=constant, eta0=0.1, AUROC=0.7279
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=constant, eta0=1, AUROC=0.6930
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=adaptive, eta0=0.01, AUROC=0.7572
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=adaptive, eta0=0.1, AUROC=0.7601
# Parameters: alpha=0.1, penalty=elasticnet, learning_rate=adaptive, eta0=1, AUROC=0.7604
#
# Best Parameters: {'alpha': 0.001, 'penalty': 'l1', 'learning_rate': 'constant', 'eta0': 0.01}
# Best Validation AUROC score: 0.8884

# %%
# Predict on training data
pred_probas_train = clf.predict_proba(X_train)
risk_groups_train = results(pred_probas_train)

# Compute ROC curve and area under the curve
fpr, tpr, thresholds = roc_curve(y_train, pred_probas_train[:,1])
roc_auc = auc(fpr, tpr)
plot_ROC_curve(fpr, tpr, roc_auc, 'Training curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_train, auroc_ci_upper_train = bootstrap_metric_ci(y_train, pred_probas_train[:,1], "auroc")

print(f"Training AUROC: {roc_auc:.3f} (95% CI: {auroc_ci_lower_train:.3f}, {auroc_ci_upper_train:.3f})")
# Out:
# Training AUROC: 0.887 (95% CI: 0.860, 0.911)

# %%
# Evaluate on validation set
print("\nVal")
pred_probas_val = clf.predict_proba(X_val)
risk_groups_val = results(pred_probas_val)

# Compute ROC curve and area under the curve for validation set
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, pred_probas_val[:,1])
roc_auc_val = auc(fpr_val, tpr_val)
plot_ROC_curve(fpr_val, tpr_val, roc_auc_val, 'Validation curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_val, auroc_ci_upper_val = bootstrap_metric_ci(y_val, pred_probas_val[:,1], "auroc")

print(f"Val AUROC: {roc_auc_val:.3f} (95% CI: {auroc_ci_lower_val:.3f}, {auroc_ci_upper_val:.3f})")
# Out:
# Val
# Val AUROC: 0.888 (95% CI: 0.835, 0.938)
