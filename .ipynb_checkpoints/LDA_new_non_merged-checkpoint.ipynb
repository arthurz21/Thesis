# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
import os
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import shap
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import precision_score, recall_score, f1_score
from copy import deepcopy
from math import sqrt
from sklearn.utils import resample
from sklearn.metrics import make_scorer, recall_score

# %%
derivation_cohort = pd.read_csv("Derivation_dataset.csv")
external_validation_cohort = pd.read_csv("External_validation_dataset.csv")

y = derivation_cohort['Outcome_Occlusion_MI']
X = derivation_cohort.drop('Outcome_Occlusion_MI', axis=1)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify = y, random_state = 99)

for el in X_train.columns:
    X_train[el].fillna(X_train[el].mode()[0], inplace=True)
    X_val[el].fillna(X_train[el].mode()[0], inplace=True)

y_train = np.ravel(np.array(y_train.values))
y_val = np.ravel(np.array(y_val.values))

columns = X_train.columns

X_train = np.array(X_train.values)
X_val = np.array(X_val.values)

scaler = preprocessing.StandardScaler().fit(X_train) # Compute mean and std of training set
X_train = scaler.transform(X_train, copy=True)
X_val = scaler.transform(X_val, copy=True)
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_78024\1077325655.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[el].fillna(X_train[el].mode()[0], inplace=True)
# C:\Users\arthu\AppData\Local\Temp\ipykernel_78024\1077325655.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_val[el].fillna(X_train[el].mode()[0], inplace=True)

# %%
def plot_ROC_curve(fpr, tpr, roc_auc, title):
    plt.figure(figsize=[5, 5])
    plt.title(title)
    plt.plot(fpr, tpr, color='b',
                 label=r'LDA (AUC = %0.3f)' % (roc_auc),
                 lw=2, alpha=.8)
    plt.plot([0, 1], [0, 1], linestyle='--', lw=1, color='grey', alpha=.5)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate = 1 - Specificity')
    plt.ylabel('True Positive Rate = Sensitivity')
    plt.legend(loc="lower right")
    plt.show()

# %%
def results(pred_probas):
    OMI_score = np.round(pred_probas[:, 1]*100, decimals=2)
    y_pred = np.where(OMI_score<5, 'Low risk', 'Intermediate risk')
    y_pred = np.where(OMI_score>=20, 'High risk', y_pred)
    
    results = {
        'Low risk': [np.count_nonzero(y_pred == 'Low risk')],
        'Intermediate risk': [np.count_nonzero(y_pred == 'Intermediate risk')],
        'High risk': [np.count_nonzero(y_pred == 'High risk')]
    }
    return(pd.DataFrame(data=results, index=['Count (N)']))

# %%
def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=1000, alpha=0.05):
    """
    Compute 95% confidence interval using bootstrapping for any metric.
    
    Parameters:
    - y_true: Ground truth labels (0 or 1).
    - y_pred: Predicted values (either probabilities or binary predictions).
    - metric_fn: Metric function (roc_auc_score, recall_score, f1_score).
    - n_bootstrap: Number of bootstrap resamples.
    - alpha: Significance level (default 0.05 for 95% CI).

    Returns:
    - Lower and upper bound of the confidence interval.
    """
    scores = []
    
    for _ in range(n_bootstrap):
        # Resample dataset with replacement
        indices = resample(range(len(y_true)), replace=True, n_samples=len(y_true))
        y_true_bootstrap = np.array(y_true)[indices]
        y_pred_bootstrap = np.array(y_pred)[indices]

        # Special case for AUROC: Use roc_curve and auc()
        if metric_fn == "auroc":
            fpr, tpr, _ = roc_curve(y_true_bootstrap, y_pred_bootstrap)
            score = auc(fpr, tpr)
        else:
            score = metric_fn(y_true_bootstrap, y_pred_bootstrap)

        scores.append(score)
    
    # Compute confidence interval
    lower_bound = np.percentile(scores, 100 * (alpha / 2))
    upper_bound = np.percentile(scores, 100 * (1 - alpha / 2))
    
    return lower_bound, upper_bound

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import roc_auc_score

print("Hyperparameter Tuning on Validation Set")
best_score = 0
best_params = {}
best_model = None
print("Searching for optimal hyperparameters...")
for solver in ['svd', 'lsqr', 'eigen']:  # LDA solvers
    for shrinkage in [None, 'auto', 0.01, 0.1, 0.5, 1] if solver in ['lsqr', 'eigen'] else [None]:  
        for tol in [1e-4, 1e-3, 1e-2, 1e-1]:  # Tolerance values
            try:
                # Create and train LDA model with current parameters
                current_lda = LinearDiscriminantAnalysis(solver=solver, shrinkage=shrinkage, tol=tol)
                
                # Train on training set
                current_lda.fit(X_train, y_train)
                
                # Evaluate on validation set using AUROC
                val_probas = current_lda.predict_proba(X_val)[:, 1]  # Get positive class probabilities
                auroc_val = roc_auc_score(y_val, val_probas)
                
                print(f"Parameters: solver={solver}, shrinkage={shrinkage}, tol={tol}, AUROC={auroc_val:.4f}")
                
                # Track best model based on AUROC
                if auroc_val > best_score:
                    best_score = auroc_val
                    best_params = {'solver': solver, 'shrinkage': shrinkage, 'tol': tol}
                    best_model = current_lda
                    
            except Exception as e:
                print(f"Error with parameters: solver={solver}, shrinkage={shrinkage}, tol={tol}")
                print(f"Error message: {str(e)}")
                continue

print(f"\nBest Parameters: {best_params}")
print(f"Best Validation AUROC score: {best_score:.4f}")
# Use the best model found
clf = best_model
# Out:
# Hyperparameter Tuning on Validation Set
# Searching for optimal hyperparameters...
# Parameters: solver=svd, shrinkage=None, tol=0.0001, AUROC=0.8816
# Parameters: solver=svd, shrinkage=None, tol=0.001, AUROC=0.8816
# Parameters: solver=svd, shrinkage=None, tol=0.01, AUROC=0.8816
# Parameters: solver=svd, shrinkage=None, tol=0.1, AUROC=0.8819
# Parameters: solver=lsqr, shrinkage=None, tol=0.0001, AUROC=0.8816
# Parameters: solver=lsqr, shrinkage=None, tol=0.001, AUROC=0.8816
# Parameters: solver=lsqr, shrinkage=None, tol=0.01, AUROC=0.8816
# Parameters: solver=lsqr, shrinkage=None, tol=0.1, AUROC=0.8816
# Parameters: solver=lsqr, shrinkage=auto, tol=0.0001, AUROC=0.8794
# Parameters: solver=lsqr, shrinkage=auto, tol=0.001, AUROC=0.8794
# Parameters: solver=lsqr, shrinkage=auto, tol=0.01, AUROC=0.8794
# Parameters: solver=lsqr, shrinkage=auto, tol=0.1, AUROC=0.8794
# Parameters: solver=lsqr, shrinkage=0.01, tol=0.0001, AUROC=0.8822
# Parameters: solver=lsqr, shrinkage=0.01, tol=0.001, AUROC=0.8822
# Parameters: solver=lsqr, shrinkage=0.01, tol=0.01, AUROC=0.8822
# Parameters: solver=lsqr, shrinkage=0.01, tol=0.1, AUROC=0.8822
# Parameters: solver=lsqr, shrinkage=0.1, tol=0.0001, AUROC=0.8716
# Parameters: solver=lsqr, shrinkage=0.1, tol=0.001, AUROC=0.8716
# Parameters: solver=lsqr, shrinkage=0.1, tol=0.01, AUROC=0.8716
# Parameters: solver=lsqr, shrinkage=0.1, tol=0.1, AUROC=0.8716
# Parameters: solver=lsqr, shrinkage=0.5, tol=0.0001, AUROC=0.8130
# Parameters: solver=lsqr, shrinkage=0.5, tol=0.001, AUROC=0.8130
# Parameters: solver=lsqr, shrinkage=0.5, tol=0.01, AUROC=0.8130
# Parameters: solver=lsqr, shrinkage=0.5, tol=0.1, AUROC=0.8130
# Parameters: solver=lsqr, shrinkage=1, tol=0.0001, AUROC=0.7212
# Parameters: solver=lsqr, shrinkage=1, tol=0.001, AUROC=0.7212
# Parameters: solver=lsqr, shrinkage=1, tol=0.01, AUROC=0.7212
# Parameters: solver=lsqr, shrinkage=1, tol=0.1, AUROC=0.7212
# Parameters: solver=eigen, shrinkage=None, tol=0.0001, AUROC=0.8816
# Parameters: solver=eigen, shrinkage=None, tol=0.001, AUROC=0.8816
# Parameters: solver=eigen, shrinkage=None, tol=0.01, AUROC=0.8816
# Parameters: solver=eigen, shrinkage=None, tol=0.1, AUROC=0.8816
# Parameters: solver=eigen, shrinkage=auto, tol=0.0001, AUROC=0.8794
# Parameters: solver=eigen, shrinkage=auto, tol=0.001, AUROC=0.8794
# Parameters: solver=eigen, shrinkage=auto, tol=0.01, AUROC=0.8794
# Parameters: solver=eigen, shrinkage=auto, tol=0.1, AUROC=0.8794
# Parameters: solver=eigen, shrinkage=0.01, tol=0.0001, AUROC=0.8822
# Parameters: solver=eigen, shrinkage=0.01, tol=0.001, AUROC=0.8822
# Parameters: solver=eigen, shrinkage=0.01, tol=0.01, AUROC=0.8822
# Parameters: solver=eigen, shrinkage=0.01, tol=0.1, AUROC=0.8822
# Parameters: solver=eigen, shrinkage=0.1, tol=0.0001, AUROC=0.8716
# Parameters: solver=eigen, shrinkage=0.1, tol=0.001, AUROC=0.8716
# Parameters: solver=eigen, shrinkage=0.1, tol=0.01, AUROC=0.8716
# Parameters: solver=eigen, shrinkage=0.1, tol=0.1, AUROC=0.8716
# Parameters: solver=eigen, shrinkage=0.5, tol=0.0001, AUROC=0.8130
# Parameters: solver=eigen, shrinkage=0.5, tol=0.001, AUROC=0.8130
# Parameters: solver=eigen, shrinkage=0.5, tol=0.01, AUROC=0.8130
# Parameters: solver=eigen, shrinkage=0.5, tol=0.1, AUROC=0.8130
# Parameters: solver=eigen, shrinkage=1, tol=0.0001, AUROC=0.7212
# Parameters: solver=eigen, shrinkage=1, tol=0.001, AUROC=0.7212
# Parameters: solver=eigen, shrinkage=1, tol=0.01, AUROC=0.7212
# Parameters: solver=eigen, shrinkage=1, tol=0.1, AUROC=0.7212
#
# Best Parameters: {'solver': 'lsqr', 'shrinkage': 0.01, 'tol': 0.0001}
# Best Validation AUROC score: 0.8822

# %%
# Predict on training data
pred_probas_train = clf.predict_proba(X_train)
risk_groups_train = results(pred_probas_train)

# Compute ROC curve and area under the curve
fpr, tpr, thresholds = roc_curve(y_train, pred_probas_train[:,1])
roc_auc = auc(fpr, tpr)
plot_ROC_curve(fpr, tpr, roc_auc, 'Training curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_train, auroc_ci_upper_train = bootstrap_metric_ci(y_train, pred_probas_train[:,1], "auroc")

print(f"Training AUROC: {roc_auc:.3f} (95% CI: {auroc_ci_lower_train:.3f}, {auroc_ci_upper_train:.3f})")
# Out:
# Training AUROC: 0.878 (95% CI: 0.850, 0.906)

# %%
# Evaluate on validation set
print("\nVal")
pred_probas_val = clf.predict_proba(X_val)
risk_groups_val = results(pred_probas_val)

# Compute ROC curve and area under the curve for validation set
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, pred_probas_val[:,1])
roc_auc_val = auc(fpr_val, tpr_val)
plot_ROC_curve(fpr_val, tpr_val, roc_auc_val, 'Validation curve: Derivation cohort (ROC curves)')

# Compute AUROC CI
auroc_ci_lower_val, auroc_ci_upper_val = bootstrap_metric_ci(y_val, pred_probas_val[:,1], "auroc")

print(f"Val AUROC: {roc_auc_val:.3f} (95% CI: {auroc_ci_lower_val:.3f}, {auroc_ci_upper_val:.3f})")
# Out:
# Val
# Val AUROC: 0.882 (95% CI: 0.827, 0.926)
